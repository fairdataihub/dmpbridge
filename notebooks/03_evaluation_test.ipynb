# %%
from pathlib import Path

from dmpbridge.evaluation.evaluator import (
    evaluate_folder,
    print_evaluation_report
)

results = evaluate_folder(
    extracted_folder=Path("../data/structure_json"),
    reference_folder=Path("../data/reference_json"),
    output_path=Path("../outputs/evaluation_results.json")
)

print_evaluation_report(results)
# Out:
# sample10_pdfplumber
#    Missing reference file: ..\data\reference_json\sample10_reference.json
#
# sample11_pdfplumber
#    Missing reference file: ..\data\reference_json\sample11_reference.json
#
# sample1_pdfplumber
#   Word Capture:   0.996
#   ROUGE-L:        0.996
#   Number Capture: 1.0
#   Section Match:  1.0
#   Answer Match:   0.996
#   JSON Valid:     True
#   Status:          Passed
#
# sample2_pdfplumber
#   Word Capture:   0.997
#   ROUGE-L:        0.993
#   Number Capture: 1.0
#   Section Match:  1.0
#   Answer Match:   0.993
#   JSON Valid:     True
#   Status:          Passed
#
# sample3_pdfplumber
#   Word Capture:   1.0
#   ROUGE-L:        1.0
#   Number Capture: 1.0
#   Section Match:  1.0
#   Answer Match:   1.0
#   JSON Valid:     True
#   Status:          Passed
#
# sample4_pdfplumber
#    Missing reference file: ..\data\reference_json\sample4_reference.json
#
# sample5_pdfplumber
#    Missing reference file: ..\data\reference_json\sample5_reference.json
#
# ...
