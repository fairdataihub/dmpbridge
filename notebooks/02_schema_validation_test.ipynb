# %%
from pathlib import Path
from dmpbridge.validation.schema_validator import (
    validate_structure_json_folder,
    print_validation_report
)

results = validate_structure_json_folder(
    folder_path=Path("../data/structure_json")
)

print_validation_report(results)
# Out:
# [2026-05-15 14:33:42] Validation passed for sample10_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample11_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample1_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample2_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample3_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample4_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample5_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample6_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample7_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample8_pdfplumber.json
# [2026-05-15 14:33:42] Validation passed for sample9_pdfplumber.json
#
# sample10_pdfplumber.json
#    Passed
#
# sample11_pdfplumber.json
#    Passed
#
# sample1_pdfplumber.json
#    Passed
#
# sample2_pdfplumber.json
#    Passed
#
# sample3_pdfplumber.json
#    Passed
#
# ...
