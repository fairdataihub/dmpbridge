# %% [markdown]
# # Simple Block Comparison Evaluation
#
# This notebook compares **manual/reference JSON blocks** with **Llama/AI detected JSON blocks**.
#
# It answers only three questions for each manual block:
#
# 1. **Did Llama find similar text?**
# 2. **Did Llama give the correct label?**
# 3. **Was it in the correct order?**
#
# It also creates:
#
# - overall summary per sample
# - block-level comparison report
# - per-label accuracy
# - label confusion table
# - unmatched/extra Llama blocks

# %% [markdown]
# ## Step 1 — Import libraries

# %%
from pathlib import Path
import json
import re
from difflib import SequenceMatcher

import pandas as pd

pd.set_option('display.max_colwidth', 120)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## Step 2 — Set project folders
#
# Update these folders only if your files are somewhere else.
#
# Expected file names:
#
# - `sample1_reference_blocks.json`
# - `sample1_llama_blocks.json`
#
# The code also handles names like `sample1_reference__blocks.json`.

# %%
# Find project root
cwd = Path.cwd()

if (cwd / 'data').exists():
    project_root = cwd
elif (cwd.parent / 'data').exists():
    project_root = cwd.parent
else:
    # Fallback for uploaded files in this environment
    project_root = Path('/mnt/data')

# Main folders
reference_dir = project_root / 'data' / 'reference_structure_blocks'
llama_dir = project_root / 'data' / 'llama_structured_blocks'

# If folders do not exist, use /mnt/data for uploaded sample files
if not reference_dir.exists():
    reference_dir = Path('/mnt/data')
if not llama_dir.exists():
    llama_dir = Path('/mnt/data')

output_dir = project_root / 'data' / 'block_comparison_reports_simple'
if project_root == Path('/mnt/data'):
    output_dir = Path('/mnt/data/block_comparison_reports_simple')

output_dir.mkdir(parents=True, exist_ok=True)

print('Project root:', project_root)
print('Reference folder:', reference_dir)
print('Llama folder:', llama_dir)
print('Output folder:', output_dir)
# Out:
# Project root: c:\Users\Nahid\dmpbridge
# Reference folder: c:\Users\Nahid\dmpbridge\data\reference_structure_blocks
# Llama folder: c:\Users\Nahid\dmpbridge\data\llama_structured_blocks
# Output folder: c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple

# %% [markdown]
# ## Step 3 — Find JSON files

# %%
reference_files = sorted(reference_dir.glob('*reference*blocks*.json'))
llama_files = sorted(llama_dir.glob('*llama*blocks*.json'))

print('Reference files:')
for f in reference_files:
    print(' -', f.name)

print('Llama files:')
for f in llama_files:
    print(' -', f.name)
# Out:
# Reference files:
#  - sample10_reference_blocks.json
#  - sample1_reference_blocks.json
#  - sample2_reference_blocks.json
#  - sample3_reference_blocks.json
#  - sample4_reference_blocks.json
#  - sample5_reference_blocks.json
#  - sample6_reference_blocks.json
#  - sample7_reference_blocks.json
#  - sample8_reference_blocks.json
#  - sample9_reference_blocks.json
# Llama files:
#  - sample10_llama_blocks.json
#  - sample1_llama_blocks.json
#  - sample2_llama_blocks.json
#  - sample3_llama_blocks.json
#  - sample4_llama_blocks.json
#  - sample5_llama_blocks.json
#  - sample6_llama_blocks.json
#  - sample7_llama_blocks.json
#  - sample8_llama_blocks.json
#  - sample9_llama_blocks.json

# %% [markdown]
# ## Step 4 — Helper functions
#
# These functions keep the comparison simple:
#
# - clean text before matching
# - extract sample ID from file name
# - compute text similarity
# - load JSON blocks

# %%
def normalize_text(text):
    """Clean text so small formatting differences do not hurt matching."""
    if text is None:
        return ''
    text = str(text)
    text = text.replace('\n', ' ').replace('	', ' ')
    text = text.replace('“', '"').replace('”', '"').replace('’', "'")
    text = text.replace('–', '-').replace('—', '-')
    text = re.sub(r'\s+', ' ', text)
    return text.strip().lower()


def token_set_similarity(a, b):
    """Word overlap similarity between two text blocks."""
    a_tokens = set(normalize_text(a).split())
    b_tokens = set(normalize_text(b).split())
    if not a_tokens or not b_tokens:
        return 0.0
    return len(a_tokens & b_tokens) / len(a_tokens | b_tokens)


def sequence_similarity(a, b):
    """Character/order similarity between two text blocks."""
    return SequenceMatcher(None, normalize_text(a), normalize_text(b)).ratio()


def combined_similarity(a, b):
    """Final text similarity score: 60% sequence + 40% word overlap."""
    return (0.60 * sequence_similarity(a, b)) + (0.40 * token_set_similarity(a, b))


def sample_id_from_filename(path):
    """Extract sample ID from a file name."""
    name = path.stem.lower()
    name = name.replace('_reference__blocks', '')
    name = name.replace('_reference_blocks', '')
    name = name.replace('_llama_blocks', '')
    name = name.replace('-reference-blocks', '')
    name = name.replace('-llama-blocks', '')
    return name


def load_blocks(json_path):
    """Load blocks from JSON and keep only index, label, text."""
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Some JSON files may store blocks inside a dictionary
    if isinstance(data, dict):
        for key in ['blocks', 'structured_blocks', 'data']:
            if key in data and isinstance(data[key], list):
                data = data[key]
                break

    blocks = []
    for i, block in enumerate(data, start=1):
        if not isinstance(block, dict):
            continue
        label = str(block.get('label', '')).strip()
        text = str(block.get('text', '')).strip()
        if not text:
            continue
        blocks.append({
            'idx': i,
            'label': label,
            'text': text,
            'norm_text': normalize_text(text)
        })
    return blocks

# %% [markdown]
# ## Step 5 — Set simple evaluation rules
#
# A block is counted as **text found** when similarity is at least `SIMILARITY_THRESHOLD`.
#
# A block is counted as **order correct** when the reference index and Llama index are within `ORDER_TOLERANCE` positions.

# %%
SIMILARITY_THRESHOLD = 0.75
ORDER_TOLERANCE = 1

print('Similarity threshold:', SIMILARITY_THRESHOLD)
print('Order tolerance:', ORDER_TOLERANCE)
# Out:
# Similarity threshold: 0.75
# Order tolerance: 1

# %% [markdown]
# ## Step 6 — Compare one sample

# %%
def make_error_type(similar_text_found, label_correct, order_correct):
    """Simple explanation for each reference block."""
    if not similar_text_found:
        return 'text_not_found'
    if similar_text_found and not label_correct:
        return 'label_wrong'
    if similar_text_found and label_correct and not order_correct:
        return 'order_wrong'
    return 'correct'


def compare_sample(sample_id, reference_path, llama_path,
                   similarity_threshold=SIMILARITY_THRESHOLD,
                   order_tolerance=ORDER_TOLERANCE):
    """Compare one reference JSON file with one Llama JSON file."""

    reference_blocks = load_blocks(reference_path)
    llama_blocks = load_blocks(llama_path)

    used_llama_indices = set()
    rows = []

    for ref in reference_blocks:
        best = None
        best_score = -1

        # Find best unused Llama block by text similarity
        for llama in llama_blocks:
            if llama['idx'] in used_llama_indices:
                continue

            score = combined_similarity(ref['text'], llama['text'])
            if score > best_score:
                best_score = score
                best = llama

        similar_text_found = best is not None and best_score >= similarity_threshold

        if similar_text_found:
            used_llama_indices.add(best['idx'])

            label_correct = ref['label'] == best['label']
            order_difference = abs(ref['idx'] - best['idx'])
            order_correct = order_difference <= order_tolerance

            llama_idx = best['idx']
            llama_label = best['label']
            llama_text = best['text']
        else:
            label_correct = False
            order_difference = None
            order_correct = False
            llama_idx = None
            llama_label = None
            llama_text = None

        rows.append({
            'sample_id': sample_id,
            'ref_idx': ref['idx'],
            'ref_label': ref['label'],
            'ref_text': ref['text'],
            'llama_idx': llama_idx,
            'llama_label': llama_label,
            'llama_text': llama_text,
            'similarity_score': round(best_score, 3) if best_score >= 0 else None,
            'similar_text_found': similar_text_found,
            'label_correct': label_correct,
            'order_difference': order_difference,
            'order_correct': order_correct,
            'error_type': make_error_type(similar_text_found, label_correct, order_correct)
        })

    # Extra Llama blocks: detected by Llama but not matched to any reference block
    extra_rows = []
    for llama in llama_blocks:
        if llama['idx'] not in used_llama_indices:
            extra_rows.append({
                'sample_id': sample_id,
                'llama_idx': llama['idx'],
                'llama_label': llama['label'],
                'llama_text': llama['text'],
                'issue': 'extra_or_unmatched_llama_block'
            })

    block_report = pd.DataFrame(rows)
    extra_report = pd.DataFrame(extra_rows)

    return block_report, extra_report, reference_blocks, llama_blocks

# %% [markdown]
# ## Step 7 — Match reference files with Llama files

# %%
reference_map = {sample_id_from_filename(f): f for f in reference_files}
llama_map = {sample_id_from_filename(f): f for f in llama_files}

common_sample_ids = sorted(set(reference_map) & set(llama_map))

print('Matched sample IDs:')
for sid in common_sample_ids:
    print(' -', sid)

missing_llama = sorted(set(reference_map) - set(llama_map))
missing_reference = sorted(set(llama_map) - set(reference_map))

if missing_llama:print('Reference files without matching Llama file:', missing_llama)
if missing_reference:
    print('Llama files without matching reference file:', missing_reference)
# Out:
# Matched sample IDs:
#  - sample1
#  - sample10
#  - sample2
#  - sample3
#  - sample4
#  - sample5
#  - sample6
#  - sample7
#  - sample8
#  - sample9

# %% [markdown]
# ## Step 8 — Run comparison for all samples

# %%
all_block_reports = []
all_extra_reports = []
summary_rows = []

for sample_id in common_sample_ids:
    block_report, extra_report, reference_blocks, llama_blocks = compare_sample(
        sample_id,
        reference_map[sample_id],
        llama_map[sample_id]
    )

    all_block_reports.append(block_report)
    all_extra_reports.append(extra_report)

    total_ref = len(reference_blocks)
    total_llama = len(llama_blocks)

    text_found = int(block_report['similar_text_found'].sum())
    label_correct = int(block_report['label_correct'].sum())
    order_correct = int(block_report['order_correct'].sum())
    wrong_or_missing = int((block_report['error_type'] != 'correct').sum())

    summary_rows.append({
        'sample_id': sample_id,
        'reference_blocks': total_ref,
        'llama_blocks': total_llama,
        'text_found': text_found,
        'label_correct': label_correct,
        'order_correct': order_correct,
        'wrong_or_missing': wrong_or_missing,
        'extra_llama_blocks': len(extra_report),
        'text_match_rate': round(text_found / total_ref, 3) if total_ref else 0,
        'label_accuracy': round(label_correct / total_ref, 3) if total_ref else 0,
        'order_accuracy': round(order_correct / total_ref, 3) if total_ref else 0
    })

block_level_report = pd.concat(all_block_reports, ignore_index=True) if all_block_reports else pd.DataFrame()
extra_llama_report = pd.concat(all_extra_reports, ignore_index=True) if all_extra_reports else pd.DataFrame()
summary_report = pd.DataFrame(summary_rows)

summary_report
# Out:
#   sample_id  reference_blocks  llama_blocks  text_found  label_correct  \
# 0   sample1                28            28          28             28
# 1  sample10                13            13          13             13
# 2   sample2                12            38           9              7
# 3   sample3                14            10           8              3
# 4   sample4                 2             2           2              2
# 5   sample5                13            28           9              9
# 6   sample6                11            11           3              3
# 7   sample7                 2             2           2              2
# 8   sample8                13            13          13             13
# 9   sample9                11            12          11              9
#
#    order_correct  wrong_or_missing  extra_llama_blocks  text_match_rate  \
# 0             28                 0                   0            1.000
# 1             13                 0                   0            1.000
# 2              3                10                  29            0.750
# 3              3                13                   2            0.571
# 4              2                 0                   0            1.000
# 5              1                12                  19            0.692
# 6              3                 8                   8            0.273
# 7              2                 0                   0            1.000
# 8             13                 0                   0            1.000
# 9             11                 2                   1            1.000
#
#    label_accuracy  order_accuracy
# 0           1.000           1.000
# 1           1.000           1.000
# 2           0.583           0.250
# 3           0.214           0.214
# 4           1.000           1.000
# 5           0.692           0.077
# 6           0.273           0.273
# 7           1.000           1.000
# 8           1.000           1.000
# 9           0.818           1.000

# %% [markdown]
# ## Step 9 — Block-level report
#
# This is the most important table. Each row is one manual/reference block.
#
# Look at:
#
# - `similar_text_found`
# - `label_correct`
# - `order_correct`
# - `error_type`

# %%
display_cols = [
    'sample_id', 'ref_idx', 'ref_label', 'llama_idx', 'llama_label',
    'similarity_score', 'similar_text_found', 'label_correct',
    'order_difference', 'order_correct', 'error_type', 'ref_text', 'llama_text'
]

block_level_report[display_cols]
# Out:
#     sample_id  ref_idx       ref_label  llama_idx     llama_label  \
# 0     sample1        1  document_title        1.0  document_title
# 1     sample1        2         section        2.0         section
# 2     sample1        3      subsection        3.0      subsection
# 3     sample1        4         content        4.0         content
# 4     sample1        5      subsection        5.0      subsection
# 5     sample1        6         content        6.0         content
# 6     sample1        7      subsection        7.0      subsection
# 7     sample1        8         content        8.0         content
# 8     sample1        9         section        9.0         section
# 9     sample1       10         content       10.0         content
# 10    sample1       11         section       11.0         section
# 11    sample1       12         content       12.0         content
# 12    sample1       13         section       13.0         section
# 13    sample1       14      subsection       14.0      subsection
# 14    sample1       15         content       15.0         content
# 15    sample1       16      subsection       16.0      subsection
# 16    sample1       17         content       17.0         content
# 17    sample1       18      subsection       18.0      subsection
# 18    sample1       19         content       19.0         content
# 19    sample1       20         section       20.0         section
# 20    sample1       21      subsection       21.0      subsection
# 21    sample1       22         content       22.0         content
# 22    sample1       23      subsection       23.0      subsection
# 23    sample1       24         content       24.0         content
# 24    sample1       25      subsection       25.0      subsection
# 25    sample1       26         content       26.0         content
# 26    sample1       27         section       27.0         section
# 27    sample1       28         content       28.0         content
# 28   sample10        1  document_title        1.0  document_title
# 29   sample10        2         section        2.0         section
# 30   sample10        3         content        3.0         content
# 31   sample10        4         section        4.0         section
# 32   sample10        5         content        5.0         content
# 33   sample10        6         section        6.0         section
# 34   sample10        7         content        7.0         content
# 35   sample10        8         section        8.0         section
# 36   sample10        9         content        9.0         content
# 37   sample10       10         section       10.0         section
# 38   sample10       11         content       11.0         content
# 39   sample10       12         section       12.0         section
# 40   sample10       13         content       13.0         content
# 41    sample2        1  document_title        1.0  document_title
# 42    sample2        2         section        2.0         section
# 43    sample2        3      subsection        3.0         content
# 44    sample2        4         content        NaN            None
# 45    sample2        5         section       15.0         section
# 46    sample2        6      subsection        NaN            None
# 47    sample2        7         content       23.0         content
# 48    sample2        8         section       24.0         section
# 49    sample2        9      subsection       32.0         content
# 50    sample2       10         content        NaN            None
# 51    sample2       11         section       37.0         section
# 52    sample2       12         content       38.0         content
# 53    sample3        1  document_title        1.0         content
# 54    sample3        2         section        2.0         section
# 55    sample3        3      subsection        NaN            None
# 56    sample3        4         content        NaN            None
# 57    sample3        5         section        4.0      subsection
# 58    sample3        6      subsection        NaN            None
# 59    sample3        7         content        5.0         content
# 60    sample3        8         section        6.0      subsection
# 61    sample3        9      subsection        NaN            None
# 62    sample3       10         content        7.0         content
# 63    sample3       11         section        8.0      subsection
# 64    sample3       12      subsection        NaN            None
# 65    sample3       13         content        NaN            None
# 66    sample3       14         section       10.0      subsection
# 67    sample4        1  document_title        1.0  document_title
# 68    sample4        2         content        2.0         content
# 69    sample5        1  document_title        NaN            None
# 70    sample5        2         section        2.0         section
# 71    sample5        3         content        NaN            None
# 72    sample5        4         section        8.0         section
# 73    sample5        5         content        NaN            None
# 74    sample5        6         section       14.0         section
# 75    sample5        7         content       15.0         content
# 76    sample5        8         section       16.0         section
# 77    sample5        9         content        NaN            None
# 78    sample5       10         section       25.0         section
# 79    sample5       11         content       26.0         content
# 80    sample5       12         section       27.0         section
# 81    sample5       13         content       28.0         content
# 82    sample6        1  document_title        1.0  document_title
# 83    sample6        2         section        NaN            None
# 84    sample6        3         content        3.0         content
# 85    sample6        4         section        NaN            None
# 86    sample6        5         content        NaN            None
# 87    sample6        6         section        NaN            None
# 88    sample6        7         content        NaN            None
# 89    sample6        8         section        NaN            None
# 90    sample6        9         content        NaN            None
# 91    sample6       10         section        NaN            None
# 92    sample6       11         content       11.0         content
# 93    sample7        1  document_title        1.0  document_title
# 94    sample7        2         content        2.0         content
# 95    sample8        1  document_title        1.0  document_title
# 96    sample8        2         section        2.0         section
# 97    sample8        3         content        3.0         content
# 98    sample8        4         section        4.0         section
# 99    sample8        5         content        5.0         content
# 100   sample8        6         section        6.0         section
# 101   sample8        7         content        7.0         content
# 102   sample8        8         section        8.0         section
# 103   sample8        9         content        9.0         content
# 104   sample8       10         section       10.0         section
# 105   sample8       11         content       11.0         content
# 106   sample8       12         section       12.0         section
# 107   sample8       13         content       13.0         content
# 108   sample9        1  document_title        1.0  document_title
# 109   sample9        2         section        3.0         section
# 110   sample9        3         content        4.0         content
# 111   sample9        4         section        5.0      subsection
# 112   sample9        5         content        6.0         content
# 113   sample9        6         section        7.0         section
# 114   sample9        7         content        8.0         content
# 115   sample9        8         section        9.0      subsection
# 116   sample9        9         content       10.0         content
# 117   sample9       10         section       11.0         section
# 118   sample9       11         content       12.0         content
#
#      similarity_score  similar_text_found  label_correct  order_difference  \
# 0               1.000                True           True               0.0
# 1               1.000                True           True               0.0
# 2               1.000                True           True               0.0
# 3               0.981                True           True               0.0
# 4               1.000                True           True               0.0
# 5               0.959                True           True               0.0
# 6               1.000                True           True               0.0
# 7               1.000                True           True               0.0
# 8               1.000                True           True               0.0
# 9               1.000                True           True               0.0
# 10              1.000                True           True               0.0
# 11              0.940                True           True               0.0
# 12              1.000                True           True               0.0
# 13              1.000                True           True               0.0
# 14              1.000                True           True               0.0
# 15              1.000                True           True               0.0
# 16              1.000                True           True               0.0
# 17              1.000                True           True               0.0
# 18              0.982                True           True               0.0
# 19              1.000                True           True               0.0
# 20              1.000                True           True               0.0
# 21              0.983                True           True               0.0
# 22              1.000                True           True               0.0
# 23              1.000                True           True               0.0
# 24              1.000                True           True               0.0
# 25              1.000                True           True               0.0
# 26              1.000                True           True               0.0
# 27              1.000                True           True               0.0
# 28              1.000                True           True               0.0
# 29              1.000                True           True               0.0
# 30              1.000                True           True               0.0
# 31              1.000                True           True               0.0
# 32              1.000                True           True               0.0
# 33              1.000                True           True               0.0
# 34              1.000                True           True               0.0
# 35              1.000                True           True               0.0
# 36              1.000                True           True               0.0
# 37              1.000                True           True               0.0
# 38              1.000                True           True               0.0
# 39              1.000                True           True               0.0
# 40              1.000                True           True               0.0
# 41              1.000                True           True               0.0
# 42              1.000                True           True               0.0
# 43              1.000                True          False               0.0
# 44              0.565               False          False               NaN
# 45              1.000                True           True              10.0
# 46              0.259               False          False               NaN
# 47              1.000                True           True              16.0
# 48              1.000                True           True              16.0
# 49              0.900                True          False              23.0
# 50              0.470               False          False               NaN
# 51              1.000                True           True              26.0
# 52              1.000                True           True              26.0
# 53              1.000                True          False               0.0
# 54              1.000                True           True               0.0
# 55              0.625               False          False               NaN
# 56              0.643               False          False               NaN
# 57              1.000                True          False               1.0
# 58              0.395               False          False               NaN
# 59              0.800                True           True               2.0
# 60              1.000                True          False               2.0
# 61              0.278               False          False               NaN
# 62              0.863                True           True               3.0
# 63              1.000                True          False               3.0
# 64              0.519               False          False               NaN
# 65              0.710               False          False               NaN
# 66              1.000                True          False               4.0
# 67              1.000                True           True               0.0
# 68              1.000                True           True               0.0
# 69              0.669               False          False               NaN
# 70              1.000                True           True               0.0
# 71              0.615               False          False               NaN
# 72              1.000                True           True               4.0
# 73              0.593               False          False               NaN
# 74              1.000                True           True               8.0
# 75              1.000                True           True               8.0
# 76              1.000                True           True               8.0
# 77              0.628               False          False               NaN
# 78              1.000                True           True              15.0
# 79              1.000                True           True              15.0
# 80              1.000                True           True              15.0
# 81              1.000                True           True              15.0
# 82              1.000                True           True               0.0
# 83              0.285               False          False               NaN
# 84              0.867                True           True               0.0
# 85              0.493               False          False               NaN
# 86              0.365               False          False               NaN
# 87              0.471               False          False               NaN
# 88              0.739               False          False               NaN
# 89              0.640               False          False               NaN
# 90              0.388               False          False               NaN
# 91              0.620               False          False               NaN
# 92              0.928                True           True               0.0
# 93              1.000                True           True               0.0
# 94              0.992                True           True               0.0
# 95              1.000                True           True               0.0
# 96              1.000                True           True               0.0
# 97              1.000                True           True               0.0
# 98              1.000                True           True               0.0
# 99              1.000                True           True               0.0
# 100             1.000                True           True               0.0
# 101             1.000                True           True               0.0
# 102             1.000                True           True               0.0
# 103             1.000                True           True               0.0
# 104             1.000                True           True               0.0
# 105             1.000                True           True               0.0
# 106             1.000                True           True               0.0
# 107             1.000                True           True               0.0
# 108             0.884                True           True               0.0
# 109             1.000                True           True               1.0
# 110             1.000                True           True               1.0
# 111             1.000                True          False               1.0
# 112             1.000                True           True               1.0
# 113             1.000                True           True               1.0
# 114             1.000                True           True               1.0
# 115             1.000                True          False               1.0
# 116             0.983                True           True               1.0
# 117             1.000                True           True               1.0
# 118             1.000                True           True               1.0
#
#      order_correct      error_type  \
# 0             True         correct
# 1             True         correct
# 2             True         correct
# 3             True         correct
# 4             True         correct
# 5             True         correct
# 6             True         correct
# 7             True         correct
# 8             True         correct
# 9             True         correct
# 10            True         correct
# 11            True         correct
# 12            True         correct
# 13            True         correct
# 14            True         correct
# 15            True         correct
# 16            True         correct
# 17            True         correct
# 18            True         correct
# 19            True         correct
# 20            True         correct
# 21            True         correct
# 22            True         correct
# 23            True         correct
# 24            True         correct
# 25            True         correct
# 26            True         correct
# 27            True         correct
# 28            True         correct
# 29            True         correct
# 30            True         correct
# 31            True         correct
# 32            True         correct
# 33            True         correct
# 34            True         correct
# 35            True         correct
# 36            True         correct
# 37            True         correct
# 38            True         correct
# 39            True         correct
# 40            True         correct
# 41            True         correct
# 42            True         correct
# 43            True     label_wrong
# 44           False  text_not_found
# 45           False     order_wrong
# 46           False  text_not_found
# 47           False     order_wrong
# 48           False     order_wrong
# 49           False     label_wrong
# 50           False  text_not_found
# 51           False     order_wrong
# 52           False     order_wrong
# 53            True     label_wrong
# 54            True         correct
# 55           False  text_not_found
# 56           False  text_not_found
# 57            True     label_wrong
# 58           False  text_not_found
# 59           False     order_wrong
# 60           False     label_wrong
# 61           False  text_not_found
# 62           False     order_wrong
# 63           False     label_wrong
# 64           False  text_not_found
# 65           False  text_not_found
# 66           False     label_wrong
# 67            True         correct
# 68            True         correct
# 69           False  text_not_found
# 70            True         correct
# 71           False  text_not_found
# 72           False     order_wrong
# 73           False  text_not_found
# 74           False     order_wrong
# 75           False     order_wrong
# 76           False     order_wrong
# 77           False  text_not_found
# 78           False     order_wrong
# 79           False     order_wrong
# 80           False     order_wrong
# 81           False     order_wrong
# 82            True         correct
# 83           False  text_not_found
# 84            True         correct
# 85           False  text_not_found
# 86           False  text_not_found
# 87           False  text_not_found
# 88           False  text_not_found
# 89           False  text_not_found
# 90           False  text_not_found
# 91           False  text_not_found
# 92            True         correct
# 93            True         correct
# 94            True         correct
# 95            True         correct
# 96            True         correct
# 97            True         correct
# 98            True         correct
# 99            True         correct
# 100           True         correct
# 101           True         correct
# 102           True         correct
# 103           True         correct
# 104           True         correct
# 105           True         correct
# 106           True         correct
# 107           True         correct
# 108           True         correct
# 109           True         correct
# 110           True         correct
# 111           True     label_wrong
# 112           True         correct
# 113           True         correct
# 114           True         correct
# 115           True     label_wrong
# 116           True         correct
# 117           True         correct
# 118           True         correct
#
#                                                                                                                     ref_text  \
# 0                                                                                           DATA MANAGEMENT AND SHARING PLAN
# 1                                                                                                      Element 1: Data Type:
# 2                                            A. Types and amount of scientific data expected to be generated in the project:
# 3    This secondary data analysis project will analyze deidentified data from 48,218 participants from eight studies and ...
# 4                                      B. Scientific data that will be preserved and shared, and the rationale for doing so:
# 5    As this is a secondary data analysis project, we will only be able to publicly share in the UC San Diego Library Rep...
# 6                                                            C. Metadata, other relevant data, and associated documentation:
# 7    In addition to the data described above, code and models will be included in the repository and in on our project’s ...
# 8                                                                            Element 2: Related Tools, Software and/or Code:
# 9    Data will be analyzed with custom code by our statistical and computer science team. ActiGraph data will be processe...
# 10                                                                                                     Element 3: Standards:
# 11   The following data will be created as a result of this project:Objective sedentary behavior metrics – no existing st...
# 12                                                           Element 4: Data Preservation, Access, and Associated Timelines:
# 13                                                        A. Repository where scientific data and metadata will be archived:
# 14                         De-identified data will be uploaded to the University of California San Diego Library repository.
# 15                                                                 B. How scientific data will be findable and identifiable:
# 16   Data will be findable via publications and on our project’s GitHub website, hosted as part of the UCSD Advance Data ...
# 17                                                          C. When and how long the scientific data will be made available:
# 18   The research community will have access to data when the main outcome manuscript has been published.$2,500 in years ...
# 19                                                                 Element 5: Access, Distribution, or Reuse Considerations:
# 20                                        A. Factors affecting subsequent access, distribution, or reuse of scientific data:
# 21   The following studies have independent data use agreement & approved paper proposal processes for use of their data ...
# 22                                                                  B. Whether access to scientific data will be controlled:
# 23   The final dataset of data from the RISE study, the iWATCH study, and NHANES cohorts will be de-identified. It will b...
# 24                                      Protections for privacy, rights, and confidentiality of human research participants:
# 25                                                               All data used in this study was de-identified prior to use.
# 26                                                                      Element 6: Oversight of Data Management and Sharing:
# 27   The PI and Trial & IRB Coordinator will provide updates and changes to the plan in the annual RPPR. The PI, Trial & ...
# 28                                                                                                           DATA MANAGEMENT
# 29                                                                                                    1. Policy and Practice
# 30   We will ensure that the data obtained and this study will be made available to the research community. The Bourns Co...
# 31                                                                                                                  2. Scope
# 32   This Data Management Plan addresses the NSF policy that primary data “commonly accepted in the scientific community ...
# 33                                                                                  3. Data and Metadata Format and Contents
# 34   We will make the proposed nano-vesicles (NETs) available to interested investigators who would like to use them in t...
# 35                                                                                      4. Accessibility and Data Protection
# 36   Materials will be searchable through a number of databases and search engines, including Google and Google Scholar. ...
# 37                                                                                                    5. Derivative Products
# 38   All materials will contain acknowledgement of NSF support as per NSF policy: “ This material is based upon work supp...
# 39                                                                                                   6. Archiving and Access
# 40   It is understood that the NSF Engineering Directorate requires data to be made available for a minimum of three year...
# 41                                                                                    Center for Bio-Inspired Energy Science
# 42                                                                                          1. Data sharing and preservation
# 43   Data management plans should describe whether and how data generated in the course of the proposed research will be ...
# 44   Roles & Responsibilities. For the proposed research, Director Samuel Stupp with help from the Executive Director of ...
# 45                                                                                              2. Data used in publications
# 46   Data management plans should describe how data used in publications resulting from the proposed research will be mad...
# 47   Research conducted within the Center will be published in appropriate scientific journals. The publisher may restric...
# 48                                                                                              3. Data management resources
# 49   Data management plans should consult and reference available information about data management resources to be used ...
# 50   DMPs should consult and reference available information about data management resources to be used in the course of ...
# 51                                                                                   4. Confidentiality, security and rights
# 52   Data management plans must protect confidentiality, personal privacy, Personally Identifiable Information and U.S. n...
# 53                                                                                                                  CPS 2015
# 54                                                                                                Roles and responsibilities
# 55   The Data Management Plan should clearly articulate how the PI and co-PIs plan to manage and disseminate data generat...
# 56   Data will be generated at each of our institutional sites. The PI at each institution will be responsible for follow...
# 57                                                                                                             Types of data
# 58   The Data Management Plan should describe the types of data, samples, physical collections, software, curriculum mate...
# 59   We will manage all scientific and technical content generated from this proposal. Our products will include 3 broad ...
# 60                                                    Policies for access and sharing and appropriate protection and privacy
# 61   The Data Management Plan should describe the period of time the data will be retained and shared; factors that limit...
# 62   Data will be made available upon request, after the conclusion of each of study. The availability of data (raw and a...
# 63                                                                                   Data storage and preservation of access
# 64   The Data Management Plan should describe the mechanisms and formats for storing data and making them accessible to o...
# 65   The servers at the Rehabilitation Institute of Chicago will serve as the central repository for all collected data. ...
# 66                                                                          Additional possible data management requirements
# 67                                                                                                      DATA MANAGEMENT PLAN
# 68   The P.I. has completed human subjects training. The research assistants will be required to complete human subjects ...
# 69                                                                        DATA MANAGEMENT PLAN REVIEW OF PROPOSAL COMPONENTS
# 70                                                                                             REVIEW OF PROPOSAL COMPONENTS
# 71   The proposal is separated into three sections. Section 2.1 characterizes the aquifer formation that each groundwater...
# 72                                                                                                             TYPES OF DATA
# 73   The PI and PhD student will be responsible for all data-related activities including: collection, documentation and ...
# 74                                                                                               DATA AND METADATA STANDARDS
# 75   The data will be shared along with a README.txt, which will describe all files, their relationships, naming conventi...
# 76                                                                                           POLICIES FOR ACCESS AND SHARING
# 77   Raw data: Detailed information about how the data were obtained, including detailed contact information or websites ...
# 78                                                                       POLICIES AND PROVISIONS FOR RE-USE, RE-DISTRIBUTION
# 79   All data deposited at Dryad will be publicly available under a CC0 license, meaning that others may freely build upo...
# 80                                                                            PLANS FOR ARCHIVING AND PRESERVATION OF ACCESS
# 81   UCSB Box will be used as the primary means to store and back up all collected input, generated output data sets and ...
# 82                                                                                                     Data Management Plan:
# 83                                                                                                         1. Types of data.
# 84   The bulk of the data generated in this project will be 1, 2, 3, and 4 dimensional arrays of numbers and bytes repres...
# 85                                                                                           2. Data and metadata standards.
# 86   The PI’s research group will adopt the longstanding practice that all generated data should be straightforwardly rep...
# 87                                                                                       3. Policies for access and sharing.
# 88   Interested parties will be able to request data and codes at the end of the project. Such parties will be responsibl...
# 89                                                                   4. Policies and provisions for re-use, re-distribution.
# 90   Simulation data will in essence grow to several terrabytes with an associated cost of storage. Data will be made pub...
# 91                                                                        5. Plans for archiving and preservation of access.
# 92   Local data will be archived on the group’s mass storage system. As mentioned above, all data generated is archived w...
# 93                                                                                                Resource/Data Sharing Plan
# 94   The study investigators are committed to the open and timely dissemination of study data. The final datasets will in...
# 95                                                                       Univ. of California, Riverside Data Management Plan
# 96                                                                                                    1. Policy and Practice
# 97   The Bourns College of Engineering (BCOE) at the University of California, Riverside , in partnership with the UCR Li...
# 98                                                                                                                  2. Scope
# 99   This Data Management Plan addresses the NSF policy that primary data “commonly accepted in the scientific community ...
# 100                                                                                  3. Data and Metadata Format and Content
# 101  The software will be made available in source code form and so will the applications developed. This will allow othe...
# 102                                                                                     4. Accessibility and Data Protection
# 103  Materials will be searchable through a number of databases and search engines, including Google and Google Scholar. ...
# 104                                                                                                   5. Derivative Products
# 105  All materials will contain acknowledgement of NSF support as per NSF policy: “ This material is based upon work supp...
# 106                                                                                                  6. Archiving and Access
# 107  If the PI leaves UCR, the products in the eScholarship series will remain stored there. PI is free to reproduce and ...
# 108                                                           CAREER: HIGH-RESOLUTION NMR FOR PARAMAGNETIC SODIUM ELECTRODES
# 109                                                                                                     Products of Research
# 110  Battery material samples will be synthesized in powder form and identified through a consistent and systematic label...
# 111                                                                                                    Data Format Standards
# 112  In order to allow for interoperability, reproducibility, and reuse, all data will be stored and saved in standard an...
# 113                                                                                                       Access and sharing
# 114  The Program Toolkit and Activity Plans developed for the educational and outreach activities in partnership with Jam...
# 115                                       Policies and provisions for re-use, re-distribution, and production of derivatives
# 116  All data will be stored in Dryad and will be available under a public domain, creative commons license (CC0). Note t...
# 117                                                         Archiving of Data, Samples, and Other Relevant Research Products
# 118  Laboratory notebooks and samples will be retained for a minimum of 5 years following the conclusion of the program a...
#
#                                                                                                                   llama_text
# 0                                                                                           DATA MANAGEMENT AND SHARING PLAN
# 1                                                                                                      Element 1: Data Type:
# 2                                            A. Types and amount of scientific data expected to be generated in the project:
# 3    This secondary data analysis project will analyze deidentified data from 48,218 participants from eight studies and ...
# 4                                      B. Scientific data that will be preserved and shared, and the rationale for doing so:
# 5    As this is a secondary data analysis project, we will only be able to publicly share in the UC San Diego Library Rep...
# 6                                                            C. Metadata, other relevant data, and associated documentation:
# 7    In addition to the data described above, code and models will be included in the repository and in on our project’s ...
# 8                                                                            Element 2: Related Tools, Software and/or Code:
# 9    Data will be analyzed with custom code by our statistical and computer science team. ActiGraph data will be processe...
# 10                                                                                                     Element 3: Standards:
# 11   The following data will be created as a result of this project:\n\nObjective sedentary behavior metrics – no existin...
# 12                                                           Element 4: Data Preservation, Access, and Associated Timelines:
# 13                                                        A. Repository where scientific data and metadata will be archived:
# 14                         De-identified data will be uploaded to the University of California San Diego Library repository.
# 15                                                                 B. How scientific data will be findable and identifiable:
# 16   Data will be findable via publications and on our project’s GitHub website, hosted as part of the UCSD Advance Data ...
# 17                                                          C. When and how long the scientific data will be made available:
# 18   The research community will have access to data when the main outcome manuscript has been published.\n\n$2,500 in ye...
# 19                                                                 Element 5: Access, Distribution, or Reuse Considerations:
# 20                                        A. Factors affecting subsequent access, distribution, or reuse of scientific data:
# 21   The following studies have independent data use agreement & approved paper proposal processes for use of their data ...
# 22                                                                  B. Whether access to scientific data will be controlled:
# 23   The final dataset of data from the RISE study, the iWATCH study, and NHANES cohorts will be de-identified. It will b...
# 24                                      Protections for privacy, rights, and confidentiality of human research participants:
# 25                                                               All data used in this study was de-identified prior to use.
# 26                                                                      Element 6: Oversight of Data Management and Sharing:
# 27   The PI and Trial & IRB Coordinator will provide updates and changes to the plan in the annual RPPR. The PI, Trial & ...
# 28                                                                                                           DATA MANAGEMENT
# 29                                                                                                    1. Policy and Practice
# 30   We will ensure that the data obtained and this study will be made available to the research community.\n\nThe Bourns...
# 31                                                                                                                  2. Scope
# 32   This Data Management Plan addresses the NSF policy that primary data “commonly accepted in the scientific community ...
# 33                                                                                  3. Data and Metadata Format and Contents
# 34   We will make the proposed nano-vesicles (NETs) available to interested investigators who would like to use them in t...
# 35                                                                                      4. Accessibility and Data Protection
# 36   Materials will be searchable through a number of databases and search engines, including Google and Google Scholar. ...
# 37                                                                                                    5. Derivative Products
# 38   All materials will contain acknowledgement of NSF support as per NSF policy: “ This material is based upon work supp...
# 39                                                                                                   6. Archiving and Access
# 40   It is understood that the NSF Engineering Directorate requires data to be made available for a minimum of three year...
# 41                                                                                    Center for Bio-Inspired Energy Science
# 42                                                                                          1. Data sharing and preservation
# 43   Data management plans should describe whether and how data generated in the course of the proposed research will be ...
# 44                                                                                                                      None
# 45                                                                                              2. Data used in publications
# 46                                                                                                                      None
# 47   Research conducted within the Center will be published in appropriate scientific journals. The publisher may restric...
# 48                                                                                              3. Data management resources
# 49   reference it in the DMP. Information about other Office of Science facilities can be found in the additional guidanc...
# 50                                                                                                                      None
# 51                                                                                   4. Confidentiality, security and rights
# 52   Data management plans must protect confidentiality, personal privacy, Personally Identifiable Information and U.S. n...
# 53                                                                                                                  CPS 2015
# 54                                                                                                Roles and responsibilities
# 55                                                                                                                      None
# 56                                                                                                                      None
# 57                                                                                                             Types of data
# 58                                                                                                                      None
# 59   The Data Management Plan should describe the types of data, samples, physical collections, software, curriculum mate...
# 60                                                    Policies for access and sharing and appropriate protection and privacy
# 61                                                                                                                      None
# 62   The Data Management Plan should describe the period of time the data will be retained and shared; factors that limit...
# 63                                                                                   Data storage and preservation of access
# 64                                                                                                                      None
# 65                                                                                                                      None
# 66                                                                          Additional possible data management requirements
# 67                                                                                                      DATA MANAGEMENT PLAN
# 68   The P.I. has completed human subjects training. The research assistants will be required to complete human subjects ...
# 69                                                                                                                      None
# 70                                                                                             REVIEW OF PROPOSAL COMPONENTS
# 71                                                                                                                      None
# 72                                                                                                             TYPES OF DATA
# 73                                                                                                                      None
# 74                                                                                               DATA AND METADATA STANDARDS
# 75   The data will be shared along with a README.txt, which will describe all files, their relationships, naming conventi...
# 76                                                                                           POLICIES FOR ACCESS AND SHARING
# 77                                                                                                                      None
# 78                                                                       POLICIES AND PROVISIONS FOR RE-USE, RE-DISTRIBUTION
# 79   All data deposited at Dryad will be publicly available under a CC0 license, meaning that others may freely build upo...
# 80                                                                            PLANS FOR ARCHIVING AND PRESERVATION OF ACCESS
# 81   UCSB Box will be used as the primary means to store and back up all collected input, generated output data sets and ...
# 82                                                                                                     Data Management Plan:
# 83                                                                                                                      None
# 84   dimensional arrays of numbers and bytes representing fluid state variables generated via computer simulations of flu...
# 85                                                                                                                      None
# 86                                                                                                                      None
# 87                                                                                                                      None
# 88                                                                                                                      None
# 89                                                                                                                      None
# 90                                                                                                                      None
# 91                                                                                                                      None
# 92   mass storage system. As mentioned above, all data generated is archived with the entire code that generated it. Addi...
# 93                                                                                                Resource/Data Sharing Plan
# 94   The study investigators are committed to the open and timely dissemination of study data. The final datasets will in...
# 95                                                                       Univ. of California, Riverside Data Management Plan
# 96                                                                                                    1. Policy and Practice
# 97   The Bourns College of Engineering (BCOE) at the University of California, Riverside , in partnership with the UCR Li...
# 98                                                                                                                  2. Scope
# 99   This Data Management Plan addresses the NSF policy that primary data “commonly accepted in the scientific community ...
# 100                                                                                  3. Data and Metadata Format and Content
# 101  The software will be made available in source code form and so will the applications developed. This will allow othe...
# 102                                                                                     4. Accessibility and Data Protection
# 103  Materials will be searchable through a number of databases and search engines, including Google and Google Scholar. ...
# 104                                                                                                   5. Derivative Products
# 105  All materials will contain acknowledgement of NSF support as per NSF policy: “ This material is based upon work supp...
# 106                                                                                                  6. Archiving and Access
# 107  If the PI leaves UCR, the products in the eScholarship series will remain stored there. PI is free to reproduce and ...
# 108                                                                      CAREER: HIGH-RESOLUTION NMR FOR PARAMAGNETIC SODIUM
# 109                                                                                                     Products of Research
# 110  Battery material samples will be synthesized in powder form and identified through a consistent and systematic label...
# 111                                                                                                    Data Format Standards
# 112  In order to allow for interoperability, reproducibility, and reuse, all data will be stored and saved in standard an...
# 113                                                                                                       Access and sharing
# 114  The Program Toolkit and Activity Plans developed for the educational and outreach activities in partnership with Jam...
# 115                                       Policies and provisions for re-use, re-distribution, and production of derivatives
# 116  All data will be stored in Dryad and will be available under a public domain, creative commons license (CC0). Note t...
# 117                                                         Archiving of Data, Samples, and Other Relevant Research Products
# 118  Laboratory notebooks and samples will be retained for a minimum of 5 years following the conclusion of the program a...

# %% [markdown]
# ## Step 10 — Show only problem blocks
#
# This table makes it easy to see **which blocks were wrong**.

# %%
problem_blocks = block_level_report[block_level_report['error_type'] != 'correct'].copy()
problem_blocks[display_cols]
# Out:
#     sample_id  ref_idx       ref_label  llama_idx llama_label  \
# 43    sample2        3      subsection        3.0     content
# 44    sample2        4         content        NaN        None
# 45    sample2        5         section       15.0     section
# 46    sample2        6      subsection        NaN        None
# 47    sample2        7         content       23.0     content
# 48    sample2        8         section       24.0     section
# 49    sample2        9      subsection       32.0     content
# 50    sample2       10         content        NaN        None
# 51    sample2       11         section       37.0     section
# 52    sample2       12         content       38.0     content
# 53    sample3        1  document_title        1.0     content
# 55    sample3        3      subsection        NaN        None
# 56    sample3        4         content        NaN        None
# 57    sample3        5         section        4.0  subsection
# 58    sample3        6      subsection        NaN        None
# 59    sample3        7         content        5.0     content
# 60    sample3        8         section        6.0  subsection
# 61    sample3        9      subsection        NaN        None
# 62    sample3       10         content        7.0     content
# 63    sample3       11         section        8.0  subsection
# 64    sample3       12      subsection        NaN        None
# 65    sample3       13         content        NaN        None
# 66    sample3       14         section       10.0  subsection
# 69    sample5        1  document_title        NaN        None
# 71    sample5        3         content        NaN        None
# 72    sample5        4         section        8.0     section
# 73    sample5        5         content        NaN        None
# 74    sample5        6         section       14.0     section
# 75    sample5        7         content       15.0     content
# 76    sample5        8         section       16.0     section
# 77    sample5        9         content        NaN        None
# 78    sample5       10         section       25.0     section
# 79    sample5       11         content       26.0     content
# 80    sample5       12         section       27.0     section
# 81    sample5       13         content       28.0     content
# 83    sample6        2         section        NaN        None
# 85    sample6        4         section        NaN        None
# 86    sample6        5         content        NaN        None
# 87    sample6        6         section        NaN        None
# 88    sample6        7         content        NaN        None
# 89    sample6        8         section        NaN        None
# 90    sample6        9         content        NaN        None
# 91    sample6       10         section        NaN        None
# 111   sample9        4         section        5.0  subsection
# 115   sample9        8         section        9.0  subsection
#
#      similarity_score  similar_text_found  label_correct  order_difference  \
# 43              1.000                True          False               0.0
# 44              0.565               False          False               NaN
# 45              1.000                True           True              10.0
# 46              0.259               False          False               NaN
# 47              1.000                True           True              16.0
# 48              1.000                True           True              16.0
# 49              0.900                True          False              23.0
# 50              0.470               False          False               NaN
# 51              1.000                True           True              26.0
# 52              1.000                True           True              26.0
# 53              1.000                True          False               0.0
# 55              0.625               False          False               NaN
# 56              0.643               False          False               NaN
# 57              1.000                True          False               1.0
# 58              0.395               False          False               NaN
# 59              0.800                True           True               2.0
# 60              1.000                True          False               2.0
# 61              0.278               False          False               NaN
# 62              0.863                True           True               3.0
# 63              1.000                True          False               3.0
# 64              0.519               False          False               NaN
# 65              0.710               False          False               NaN
# 66              1.000                True          False               4.0
# 69              0.669               False          False               NaN
# 71              0.615               False          False               NaN
# 72              1.000                True           True               4.0
# 73              0.593               False          False               NaN
# 74              1.000                True           True               8.0
# 75              1.000                True           True               8.0
# 76              1.000                True           True               8.0
# 77              0.628               False          False               NaN
# 78              1.000                True           True              15.0
# 79              1.000                True           True              15.0
# 80              1.000                True           True              15.0
# 81              1.000                True           True              15.0
# 83              0.285               False          False               NaN
# 85              0.493               False          False               NaN
# 86              0.365               False          False               NaN
# 87              0.471               False          False               NaN
# 88              0.739               False          False               NaN
# 89              0.640               False          False               NaN
# 90              0.388               False          False               NaN
# 91              0.620               False          False               NaN
# 111             1.000                True          False               1.0
# 115             1.000                True          False               1.0
#
#      order_correct      error_type  \
# 43            True     label_wrong
# 44           False  text_not_found
# 45           False     order_wrong
# 46           False  text_not_found
# 47           False     order_wrong
# 48           False     order_wrong
# 49           False     label_wrong
# 50           False  text_not_found
# 51           False     order_wrong
# 52           False     order_wrong
# 53            True     label_wrong
# 55           False  text_not_found
# 56           False  text_not_found
# 57            True     label_wrong
# 58           False  text_not_found
# 59           False     order_wrong
# 60           False     label_wrong
# 61           False  text_not_found
# 62           False     order_wrong
# 63           False     label_wrong
# 64           False  text_not_found
# 65           False  text_not_found
# 66           False     label_wrong
# 69           False  text_not_found
# 71           False  text_not_found
# 72           False     order_wrong
# 73           False  text_not_found
# 74           False     order_wrong
# 75           False     order_wrong
# 76           False     order_wrong
# 77           False  text_not_found
# 78           False     order_wrong
# 79           False     order_wrong
# 80           False     order_wrong
# 81           False     order_wrong
# 83           False  text_not_found
# 85           False  text_not_found
# 86           False  text_not_found
# 87           False  text_not_found
# 88           False  text_not_found
# 89           False  text_not_found
# 90           False  text_not_found
# 91           False  text_not_found
# 111           True     label_wrong
# 115           True     label_wrong
#
#                                                                                                                     ref_text  \
# 43   Data management plans should describe whether and how data generated in the course of the proposed research will be ...
# 44   Roles & Responsibilities. For the proposed research, Director Samuel Stupp with help from the Executive Director of ...
# 45                                                                                              2. Data used in publications
# 46   Data management plans should describe how data used in publications resulting from the proposed research will be mad...
# 47   Research conducted within the Center will be published in appropriate scientific journals. The publisher may restric...
# 48                                                                                              3. Data management resources
# 49   Data management plans should consult and reference available information about data management resources to be used ...
# 50   DMPs should consult and reference available information about data management resources to be used in the course of ...
# 51                                                                                   4. Confidentiality, security and rights
# 52   Data management plans must protect confidentiality, personal privacy, Personally Identifiable Information and U.S. n...
# 53                                                                                                                  CPS 2015
# 55   The Data Management Plan should clearly articulate how the PI and co-PIs plan to manage and disseminate data generat...
# 56   Data will be generated at each of our institutional sites. The PI at each institution will be responsible for follow...
# 57                                                                                                             Types of data
# 58   The Data Management Plan should describe the types of data, samples, physical collections, software, curriculum mate...
# 59   We will manage all scientific and technical content generated from this proposal. Our products will include 3 broad ...
# 60                                                    Policies for access and sharing and appropriate protection and privacy
# 61   The Data Management Plan should describe the period of time the data will be retained and shared; factors that limit...
# 62   Data will be made available upon request, after the conclusion of each of study. The availability of data (raw and a...
# 63                                                                                   Data storage and preservation of access
# 64   The Data Management Plan should describe the mechanisms and formats for storing data and making them accessible to o...
# 65   The servers at the Rehabilitation Institute of Chicago will serve as the central repository for all collected data. ...
# 66                                                                          Additional possible data management requirements
# 69                                                                        DATA MANAGEMENT PLAN REVIEW OF PROPOSAL COMPONENTS
# 71   The proposal is separated into three sections. Section 2.1 characterizes the aquifer formation that each groundwater...
# 72                                                                                                             TYPES OF DATA
# 73   The PI and PhD student will be responsible for all data-related activities including: collection, documentation and ...
# 74                                                                                               DATA AND METADATA STANDARDS
# 75   The data will be shared along with a README.txt, which will describe all files, their relationships, naming conventi...
# 76                                                                                           POLICIES FOR ACCESS AND SHARING
# 77   Raw data: Detailed information about how the data were obtained, including detailed contact information or websites ...
# 78                                                                       POLICIES AND PROVISIONS FOR RE-USE, RE-DISTRIBUTION
# 79   All data deposited at Dryad will be publicly available under a CC0 license, meaning that others may freely build upo...
# 80                                                                            PLANS FOR ARCHIVING AND PRESERVATION OF ACCESS
# 81   UCSB Box will be used as the primary means to store and back up all collected input, generated output data sets and ...
# 83                                                                                                         1. Types of data.
# 85                                                                                           2. Data and metadata standards.
# 86   The PI’s research group will adopt the longstanding practice that all generated data should be straightforwardly rep...
# 87                                                                                       3. Policies for access and sharing.
# 88   Interested parties will be able to request data and codes at the end of the project. Such parties will be responsibl...
# 89                                                                   4. Policies and provisions for re-use, re-distribution.
# 90   Simulation data will in essence grow to several terrabytes with an associated cost of storage. Data will be made pub...
# 91                                                                        5. Plans for archiving and preservation of access.
# 111                                                                                                    Data Format Standards
# 115                                       Policies and provisions for re-use, re-distribution, and production of derivatives
#
#                                                                                                                   llama_text
# 43   Data management plans should describe whether and how data generated in the course of the proposed research will be ...
# 44                                                                                                                      None
# 45                                                                                              2. Data used in publications
# 46                                                                                                                      None
# 47   Research conducted within the Center will be published in appropriate scientific journals. The publisher may restric...
# 48                                                                                              3. Data management resources
# 49   reference it in the DMP. Information about other Office of Science facilities can be found in the additional guidanc...
# 50                                                                                                                      None
# 51                                                                                   4. Confidentiality, security and rights
# 52   Data management plans must protect confidentiality, personal privacy, Personally Identifiable Information and U.S. n...
# 53                                                                                                                  CPS 2015
# 55                                                                                                                      None
# 56                                                                                                                      None
# 57                                                                                                             Types of data
# 58                                                                                                                      None
# 59   The Data Management Plan should describe the types of data, samples, physical collections, software, curriculum mate...
# 60                                                    Policies for access and sharing and appropriate protection and privacy
# 61                                                                                                                      None
# 62   The Data Management Plan should describe the period of time the data will be retained and shared; factors that limit...
# 63                                                                                   Data storage and preservation of access
# 64                                                                                                                      None
# 65                                                                                                                      None
# 66                                                                          Additional possible data management requirements
# 69                                                                                                                      None
# 71                                                                                                                      None
# 72                                                                                                             TYPES OF DATA
# 73                                                                                                                      None
# 74                                                                                               DATA AND METADATA STANDARDS
# 75   The data will be shared along with a README.txt, which will describe all files, their relationships, naming conventi...
# 76                                                                                           POLICIES FOR ACCESS AND SHARING
# 77                                                                                                                      None
# 78                                                                       POLICIES AND PROVISIONS FOR RE-USE, RE-DISTRIBUTION
# 79   All data deposited at Dryad will be publicly available under a CC0 license, meaning that others may freely build upo...
# 80                                                                            PLANS FOR ARCHIVING AND PRESERVATION OF ACCESS
# 81   UCSB Box will be used as the primary means to store and back up all collected input, generated output data sets and ...
# 83                                                                                                                      None
# 85                                                                                                                      None
# 86                                                                                                                      None
# 87                                                                                                                      None
# 88                                                                                                                      None
# 89                                                                                                                      None
# 90                                                                                                                      None
# 91                                                                                                                      None
# 111                                                                                                    Data Format Standards
# 115                                       Policies and provisions for re-use, re-distribution, and production of derivatives

# %% [markdown]
# ## Step 11 — Per-label accuracy
#
# This answers: How well did Llama detect `document_title`, `section`, `subsection`, and `content` separately?

# %%
if not block_level_report.empty:
    per_label_accuracy = (
        block_level_report
        .groupby('ref_label')
        .agg(
            total_blocks=('ref_label', 'count'),
            text_found=('similar_text_found', 'sum'),
            label_correct=('label_correct', 'sum'),
            order_correct=('order_correct', 'sum')
        )
        .reset_index()
    )

    per_label_accuracy['text_match_rate'] = (per_label_accuracy['text_found'] / per_label_accuracy['total_blocks']).round(3)
    per_label_accuracy['label_accuracy'] = (per_label_accuracy['label_correct'] / per_label_accuracy['total_blocks']).round(3)
    per_label_accuracy['order_accuracy'] = (per_label_accuracy['order_correct'] / per_label_accuracy['total_blocks']).round(3)
else:
    per_label_accuracy = pd.DataFrame()

per_label_accuracy
# Out:
#         ref_label  total_blocks  text_found  label_correct  order_correct  \
# 0         content            50          40             40             33
# 1  document_title            10           9              8              9
# 2         section            43          38             32             27
# 3      subsection            16          11              9             10
#
#    text_match_rate  label_accuracy  order_accuracy
# 0            0.800           0.800           0.660
# 1            0.900           0.800           0.900
# 2            0.884           0.744           0.628
# 3            0.688           0.562           0.625

# %% [markdown]
# ## Step 12 — Label confusion table
#
# This answers: When Llama gave the wrong label, what did it confuse?
#
# Example: `section → subsection`.

# %%
matched_blocks = block_level_report[block_level_report['similar_text_found'] == True].copy()

if not matched_blocks.empty:
    label_confusion = pd.crosstab(
        matched_blocks['ref_label'],
        matched_blocks['llama_label'],
        rownames=['Reference label'],
        colnames=['Llama label']
    )
else:
    label_confusion = pd.DataFrame()

label_confusion
# Out:
# Llama label      content  document_title  section  subsection
# Reference label
# content               40               0        0           0
# document_title         1               8        0           0
# section                0               0       32           6
# subsection             2               0        0           9

# %% [markdown]
# ## Step 13 — Wrong label pairs only
#
# This gives a compact list of mistakes such as `section → subsection`.

# %%
wrong_label_pairs = matched_blocks[matched_blocks['ref_label'] != matched_blocks['llama_label']].copy()

if not wrong_label_pairs.empty:
    wrong_label_summary = (
        wrong_label_pairs
        .groupby(['ref_label', 'llama_label'])
        .size()
        .reset_index(name='count')
        .sort_values('count', ascending=False)
    )
else:
    wrong_label_summary = pd.DataFrame(columns=['ref_label', 'llama_label', 'count'])

wrong_label_summary
# Out:
#         ref_label llama_label  count
# 1         section  subsection      6
# 2      subsection     content      2
# 0  document_title     content      1

# %% [markdown]
# ## Step 14 — Extra Llama blocks
#
# These are blocks detected by Llama that did not match any manual/reference block.

# %%
extra_llama_report
# Out:
#    sample_id  llama_idx     llama_label  \
# 0    sample2          4      subsection
# 1    sample2          5         content
# 2    sample2          6      subsection
# 3    sample2          7         content
# 4    sample2          8      subsection
# 5    sample2          9         content
# 6    sample2         10         section
# 7    sample2         11      subsection
# 8    sample2         12         content
# 9    sample2         13      subsection
# 10   sample2         14         content
# 11   sample2         16      subsection
# 12   sample2         17      subsection
# 13   sample2         18      subsection
# 14   sample2         19      subsection
# 15   sample2         20      subsection
# 16   sample2         21      subsection
# 17   sample2         22      subsection
# 18   sample2         25      subsection
# 19   sample2         26      subsection
# 20   sample2         27      subsection
# 21   sample2         28      subsection
# 22   sample2         29      subsection
# 23   sample2         30      subsection
# 24   sample2         31      subsection
# 25   sample2         33      subsection
# 26   sample2         34         content
# 27   sample2         35      subsection
# 28   sample2         36         content
# 29   sample3          3         content
# 30   sample3          9         content
# 31   sample5          1  document_title
# 32   sample5          3         content
# 33   sample5          4      subsection
# 34   sample5          5         content
# 35   sample5          6      subsection
# 36   sample5          7         content
# 37   sample5          9         content
# 38   sample5         10      subsection
# 39   sample5         11         content
# 40   sample5         12      subsection
# 41   sample5         13         content
# 42   sample5         17      subsection
# 43   sample5         18         content
# 44   sample5         19      subsection
# 45   sample5         20         content
# 46   sample5         21      subsection
# 47   sample5         22         content
# 48   sample5         23      subsection
# 49   sample5         24         content
# 50   sample6          2         section
# 51   sample6          4         section
# 52   sample6          5         content
# 53   sample6          6         section
# 54   sample6          7         content
# 55   sample6          8         section
# 56   sample6          9         content
# 57   sample6         10         section
# 58   sample9          2         content
#
#                                                                                                                  llama_text  \
# 0                             Roles & Responsibilities. For the proposed research, Director Samuel Stupp with help from the
# 1   Executive Director of Research will take the lead and responsibility for coordinating and ensuring data storage and ...
# 2                       Data Types and Sources. A brief, high-level description of the data to be generated or used through
# 3   the course of the proposed research and which of these are considered Digital Research Data necessary to Validate th...
# 4                        Content and Format. A statement of plans for data and metadata content and format including, where
# 5   applicable, a description of documentation plans, annotation of relevant software, and the rationale for the selecti...
# 6                         Data Sharing and Data Preservation. A description of the plans for data sharing and preservation.
# 7                                                                                   This should include, where appropriate:
# 8   the anticipated means for sharing and rationale for any restrictions on who may access the data and under what condi...
# 9                           Rationale. A discussion of the rationale or justification for the proposed data management plan
# 10  including, for example, the potential impact of the data within the immediate field and in other fields, and any bro...
# 11                                    Data management plans should provide a plan for making all research data displayed in
# 12                                  publications resulting from the proposed research open, machine-readable, and digitally
# 13                               accessible to the public at the time of publication. This includes data that are displayed
# 14                               in charts, figures, images, etc. In addition, the underlying digital research data used to
# 15                                    generate the displayed data should be made as accessible as possible to the public in
# 16                                     accordance with the Principles published in the DOE Policy for Digital Research Data
# 17                                        Management. The published article should indicate how these data can be accessed.
# 18                                      Data management plans should consult and reference available information about data
# 19                                   management resources to be used in the course of the proposed research. In particular,
# 20                                         DMPs tht explicitly or implicitly commit data management resources at a facility
# 21                                     beyond what is conventionally made available to approved users should be accompanied
# 22                                  by written approval from that facility. In determining the resources available for data
# 23                                             management at DOE Scientific User Facilities, researchers should consult the
# 24                                    published description of data management resources and practices at that facility and
# 25                   Data Repositories. Senior investigators typically archive relevant data using their own group servers.
# 26  Whenever possible, investigators will be encouraged to also copy data to a centralized data server for CBES investig...
# 27                       Data Volume. Generally, the volume of data generated by CBES researchers should not prohibit their
# 28  deposition in available repositories. However, in cases where large volumes of data are generated (e.g., temperature...
# 29  The Data Management Plan should clearly articulate how the PI and co-PIs plan to manage and disseminate data generat...
# 30  The Data Management Plan should describe the mechanisms and formats for storing data and making them accessible to o...
# 31                                                                                                     DATA MANAGEMENT PLAN
# 32  The proposal is separated into three sections.\n\nSection 2.1 characterizes the aquifer formation that each groundwa...
# 33                         • Section 2.2 estimates groundwater components of the water budget (withdrawals and consumption)
# 34                                                                                   yearly (2016-2021) at the field scale.
# 35                           • Section 2.3 integrates research and education through the Scientist Spotlight and Hydrologic
# 36                                                                                                      Sciences Workshops.
# 37  The PI and PhD student will be responsible for all data-related activities including: collection, documentation and ...
# 38                         Input data: Available data will be systematically reviewed and downloaded. These data are likely
# 39  available in the form of Microsoft Access files or Microsoft Excel spreadsheets; shapefiles or raster files;\n\nor t...
# 40                     Produced Data: Datasets will be produced in Sections 2.1-2.3 of the proposal. These datasets will be
# 41                       formatted and shared in an open format (e.g., CSV) or in illustrator files (i.e., cross sections).
# 42                  Raw data: Detailed information about how the data were obtained, including detailed contact information
# 43  or websites for direct download and citations to all datasets will be provided to allow for accessibility and correc...
# 44                        Scripts and code for analyses: All scripts and code will be archived in supplementary information
# 45  appendices in publications as well as uploaded to Zenodo through the Dryad repository submission process along with ...
# 46                  Scientist spotlight: All scientist spotlight biographies, assignments, and open-access readings will be
# 47                             posted to an online Dashboard associated with the PI’s website, which is updated bi-monthly.
# 48                            Workshop frameworks: Workshop material will be shared with UCSB’s Diversity Committee through
# 49  Google Drive; if workshop materials are fully supported by the Diversity Committee, these materials will also be sha...
# 50                                  1. Types of data. The bulk of the data generated in this project will be 1, 2, 3, and 4
# 51                                      2. Data and metadata standards. The PI’s research group will adopt the longstanding
# 52  practice that all generated data should be straightforwardly reproducible. Thus, codes are stored within the same di...
# 53                         3. Policies for access and sharing. Interested parties will be able to request data and codes at
# 54                    the end of the project. Such parties will be responsible for their own version control and execution.
# 55                          4. Policies and provisions for re-use, re-distribution. Simulation data will in essence grow to
# 56  several terrabytes with an associated cost of storage. Data will be made publicly available upon request at the end ...
# 57                            5. Plans for archiving and preservation of access. Local data will be archived on the group’s
# 58                                                                                                               ELECTRODES
#
#                              issue
# 0   extra_or_unmatched_llama_block
# 1   extra_or_unmatched_llama_block
# 2   extra_or_unmatched_llama_block
# 3   extra_or_unmatched_llama_block
# 4   extra_or_unmatched_llama_block
# 5   extra_or_unmatched_llama_block
# 6   extra_or_unmatched_llama_block
# 7   extra_or_unmatched_llama_block
# 8   extra_or_unmatched_llama_block
# 9   extra_or_unmatched_llama_block
# 10  extra_or_unmatched_llama_block
# 11  extra_or_unmatched_llama_block
# 12  extra_or_unmatched_llama_block
# 13  extra_or_unmatched_llama_block
# 14  extra_or_unmatched_llama_block
# 15  extra_or_unmatched_llama_block
# 16  extra_or_unmatched_llama_block
# 17  extra_or_unmatched_llama_block
# 18  extra_or_unmatched_llama_block
# 19  extra_or_unmatched_llama_block
# 20  extra_or_unmatched_llama_block
# 21  extra_or_unmatched_llama_block
# 22  extra_or_unmatched_llama_block
# 23  extra_or_unmatched_llama_block
# 24  extra_or_unmatched_llama_block
# 25  extra_or_unmatched_llama_block
# 26  extra_or_unmatched_llama_block
# 27  extra_or_unmatched_llama_block
# 28  extra_or_unmatched_llama_block
# 29  extra_or_unmatched_llama_block
# 30  extra_or_unmatched_llama_block
# 31  extra_or_unmatched_llama_block
# 32  extra_or_unmatched_llama_block
# 33  extra_or_unmatched_llama_block
# 34  extra_or_unmatched_llama_block
# 35  extra_or_unmatched_llama_block
# 36  extra_or_unmatched_llama_block
# 37  extra_or_unmatched_llama_block
# 38  extra_or_unmatched_llama_block
# 39  extra_or_unmatched_llama_block
# 40  extra_or_unmatched_llama_block
# 41  extra_or_unmatched_llama_block
# 42  extra_or_unmatched_llama_block
# 43  extra_or_unmatched_llama_block
# 44  extra_or_unmatched_llama_block
# 45  extra_or_unmatched_llama_block
# 46  extra_or_unmatched_llama_block
# 47  extra_or_unmatched_llama_block
# 48  extra_or_unmatched_llama_block
# 49  extra_or_unmatched_llama_block
# 50  extra_or_unmatched_llama_block
# 51  extra_or_unmatched_llama_block
# 52  extra_or_unmatched_llama_block
# 53  extra_or_unmatched_llama_block
# 54  extra_or_unmatched_llama_block
# 55  extra_or_unmatched_llama_block
# 56  extra_or_unmatched_llama_block
# 57  extra_or_unmatched_llama_block
# 58  extra_or_unmatched_llama_block

# %% [markdown]
# ## Step 15 — Save all reports

# %%
summary_path = output_dir / 'summary_report.csv'
block_path = output_dir / 'block_level_report.csv'
problem_path = output_dir / 'problem_blocks_report.csv'
per_label_path = output_dir / 'per_label_accuracy.csv'
confusion_path = output_dir / 'label_confusion_matrix.csv'
wrong_pairs_path = output_dir / 'wrong_label_pairs.csv'
extra_path = output_dir / 'extra_llama_blocks.csv'

summary_report.to_csv(summary_path, index=False)
block_level_report.to_csv(block_path, index=False)
problem_blocks.to_csv(problem_path, index=False)
per_label_accuracy.to_csv(per_label_path, index=False)
label_confusion.to_csv(confusion_path)
wrong_label_summary.to_csv(wrong_pairs_path, index=False)
extra_llama_report.to_csv(extra_path, index=False)

print('Saved reports:')
for p in [summary_path, block_path, problem_path, per_label_path, confusion_path, wrong_pairs_path, extra_path]:
    print(' -', p)
# Out:
# Saved reports:
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\summary_report.csv
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\block_level_report.csv
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\problem_blocks_report.csv
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\per_label_accuracy.csv
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\label_confusion_matrix.csv
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\wrong_label_pairs.csv
#  - c:\Users\Nahid\dmpbridge\data\block_comparison_reports_simple\extra_llama_blocks.csv

# %% [markdown]
# ## Step 16 — Simple interpretation guide
#
# Use this wording in your results:
#
# - **Text Match Rate** = how many manual blocks were found by Llama.
# - **Label Accuracy** = how many manual blocks were found with the correct label.
# - **Order Accuracy** = how many manual blocks were found in the correct/near-correct document order.
# - **Label Confusion Table** = shows which labels Llama confused, such as `section → subsection`.
#
# For each sample, your main conclusion should be:
#
# > Llama found the text well / not well, labeled the blocks correctly / incorrectly, and preserved / did not preserve document order.
