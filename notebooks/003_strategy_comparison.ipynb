# %% [markdown]
# # Prompt Strategy Comparison — All Models
#
# Compares batch, whole-document, pdf-direct, and vision-batch prompting across models on all 10 DMP samples.
#
# ## Experiment setup
#
# **Task:** Label PDF text blocks with one of five labels:
# `title` · `section.title` · `section.description` · `question.text` · `answer.text`
#
# **Key challenge:** Distinguishing `question.text` (funder requirement items) from
# `section.description` (funder context text). Both are funder-written multi-line text;
# the boundary is structural, not lexical.
#
# ## Prompt strategies
#
# | Strategy | Context per API call | Calls per document |
# |---|---|---|
# | Batch | 10 blocks + 3-block sliding context | approx. total blocks / 7 |
# | Whole-doc | Full document | 1 |
# | PDF-direct | Raw PDF bytes — no pdfplumber | 1 |
# | Vision Batch | Page PNG + pdfplumber blocks, page by page | one per page |
#
# ## Models and data
#
# | Model | Provider | Batch | Whole-doc | PDF-direct | Vision |
# |---|---|---|---|---|---|
# | llama3.3:70b | Ollama | `llama3.3-70b_batch` | `llama3.3-70b_whole_doc` | — | — |
# | llama3.1:8b | Ollama | `llama3.1-8b_batch` | `llama3.1-8b_whole_doc` | — | — |
# | qwen2.5vl:7b | Ollama | — | — | — | `qwen2.5vl-7b_vision` |
#
# Output files: `data/output/labeled/{tag}/sampleN.json`
# Ground truth: `data/input/ground_truth/`
#
# > **Note:** PDF-direct accuracy is gold-based (correct / 741 gold items). It produces ~20 paragraph blocks per sample vs ~74 pdfplumber blocks, so raw block counts are incomparable. Block-level and cross-model agreement sections exclude PDF-direct. Vision Batch uses pdfplumber line-level blocks and is fully comparable with batch and whole-doc.
#
# To regenerate a variant:
# ```
# dmpbridge-experiment experiments/llama3.3-70b-batch.yaml
# ```
#
# ## Sections
#
# 1. Availability
# 2. Overall accuracy (per-sample table with delta columns)
# 3. Per-sample accuracy (bar chart and heatmap)
# 4. F1 per label
# 5. Prompt strategy delta (batch to whole-doc, per model)
# 6. Block-level analysis (which blocks changed and why)
# 7. Cross-model agreement (how many variants agree on each block)
# 8. Error drill-down (filterable block-level inspector)
# 9. Summary

# %%
import json

from dmpbridge.evaluation.evaluate import extract_gold, evaluate_sample, match, LABELS, SHORT, LLM_DIR, MANUAL_DIR, gold_metrics
from collections import defaultdict
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np

sns.set_theme(style="ticks", palette="muted")
plt.rcParams.update({
    "figure.facecolor": "white",  "axes.facecolor": "white",
    "axes.edgecolor":   "#555",   "axes.linewidth": 0.8,
    "grid.color":       "#ddd",   "grid.linewidth": 0.5,
    "text.color":       "#111",   "axes.labelcolor": "#111",
    "xtick.color":      "#111",   "ytick.color": "#111",
    "font.size": 11,  "axes.titlesize": 13,  "axes.labelsize": 11,
    "xtick.labelsize": 10,        "ytick.labelsize": 10,
    "legend.fontsize": 10,        "legend.frameon": True,
    "figure.dpi": 120
})

# Files live in data/output/labeled/{tag}/sampleN.json
# Dark shade = batch (solid bar), light shade = whole-doc (hatched bar)
MODEL_FAMILIES = {
    "llama3.3:70b": {
        "batch":     {"tag": "llama3.3-70b_batch",     "color": "#1d4ed8", "hatch": None},
        "whole-doc": {"tag": "llama3.3-70b_whole_doc", "color": "#60a5fa", "hatch": "//"}
    },
    "llama3.1:8b": {
        "batch":     {"tag": "llama3.1-8b_batch",      "color": "#0369a1", "hatch": None},
        "whole-doc": {"tag": "llama3.1-8b_whole_doc",  "color": "#38bdf8", "hatch": "//"}
    },
        "qwen2.5vl:7b": {
        "vision-batch": {"tag": "qwen2.5vl-7b_vision", "color": "#0e7490", "hatch": "xx"}
    },
        "whole-doc":    {"tag": "claude-opus-4-8_whole_doc", "color": "#c084fc", "hatch": "//"},
        "pdf-direct":   {"tag": "claude-opus-4-8_pdf",       "color": "#059669", "hatch": ".."},
        "vision-batch": {"tag": "claude-opus-4-8_vision",    "color": "#0369a1", "hatch": "xx"}
    }
}

VARIANTS = {}
for _mname, _methods in MODEL_FAMILIES.items():
    for _method, _cfg in _methods.items():
        VARIANTS[f"{_mname} {_method}"] = _cfg

def _snum(p):
    stem = p.stem if hasattr(p, "stem") else str(p)
    return int(stem.replace("_dmp", "").replace("sample", ""))

SAMPLES = sorted(MANUAL_DIR.glob("*_dmp.json"), key=_snum)
SNAMES  = [mp.stem.replace("_dmp", "") for mp in SAMPLES]

def _f1(conf, lbl):
    tp = conf.get(lbl, {}).get(lbl, 0)
    fp = sum(conf.get(o, {}).get(lbl, 0) for o in LABELS if o != lbl)
    fn = sum(v for p, v in conf.get(lbl, {}).items() if p != lbl)
    p_ = tp / (tp + fp) if (tp + fp) else 0.
    r_ = tp / (tp + fn) if (tp + fn) else 0.
    return 2 * p_ * r_ / (p_ + r_) if (p_ + r_) else 0.

def load_variant(tag):
    rows, conf = [], defaultdict(lambda: defaultdict(int))
    use_gold_acc = tag.endswith("_pdf")  # pdf_direct: paragraph-level, use gold denominator
    for mp in SAMPLES:
        stem = mp.stem.replace("_dmp", "")
        pp   = LLM_DIR / tag / f"{stem}.json"
        if not pp.exists(): continue
        gold = extract_gold(mp)
        c    = evaluate_sample(pp, gold)
        for tl, preds in c.items():
            for pl, cnt in preds.items():
                conf[tl][pl] += cnt
        if use_gold_acc:
            tp, _, n = gold_metrics(c)
        else:
            tp = sum(c.get(l, {}).get(l, 0) for l in LABELS)
            n  = sum(sum(v.values()) for v in c.values())
        rows.append({"sample": stem, "total": n, "correct": tp,
                     "errors": n - tp, "accuracy": tp / n if n else 0})
    return (pd.DataFrame(rows), conf) if rows else (None, None)

DATA   = {name: load_variant(cfg["tag"]) for name, cfg in VARIANTS.items()}
ACTIVE = {n: d for n, d in DATA.items() if d[0] is not None}
n_v    = len(ACTIVE)
print(f"Loaded {n_v} / {len(VARIANTS)} variants.")
# Out:
# Loaded 9 / 9 variants.

# %% [markdown]
# ---
# ## Section 1 — Availability
#
# Confirms which variants have complete data across all 10 samples.

# %%
print(f"  {'Variant':<30}  {'Status':>12}  {'Samples':>7}  {'Correct':>7}  {'Total':>6}  {'Accuracy':>9}")
print("  " + "-" * 79)
for name, cfg in VARIANTS.items():
    df, _ = DATA[name]
    if df is None:
        print(f"  {name:<30}  {'missing':>12}  {'--':>7}  {'--':>7}  {'--':>6}  {'--':>9}")
    else:
        tc, tn = int(df["correct"].sum()), int(df["total"].sum())
        n_s    = len(df)
        status = "OK" if n_s == 10 else f"partial ({n_s}/10)"
        print(f"  {name:<30}  {status:>12}  {n_s:>7}  {tc:>7}  {tn:>6}  {tc/tn*100:>8.1f}%")
# Out:
#   Variant                               Status  Samples  Correct   Total   Accuracy
#   -------------------------------------------------------------------------------
#   llama3.3:70b batch                        OK       10      695     741      93.8%
#   llama3.3:70b whole-doc                    OK       10      680     741      91.8%
#   llama3.1:8b batch                         OK       10      498     741      67.2%
#   llama3.1:8b whole-doc                     OK       10      617     741      83.3%
#   qwen2.5vl:7b vision-batch                 OK       10      577     741      77.9%
#   claude-opus-4-8 batch                     OK       10      703     741      94.9%
#   claude-opus-4-8 whole-doc                 OK       10      718     741      96.9%
#   claude-opus-4-8 pdf-direct                OK       10      193     203      95.1%
#   claude-opus-4-8 vision-batch              OK       10      702     741      94.7%

# %% [markdown]
# ---
# ## Section 2 — Overall accuracy
#
# Per-sample block-level accuracy for every variant, with delta columns showing the
# accuracy change from switching to whole-doc within the same model family.
# Positive delta = whole-doc better; negative delta = batch better.

# %%
rows = []
for sname in SNAMES:
    row = {"sample": sname}
    for vname, (df, _) in ACTIVE.items():
        sub = df[df["sample"] == sname]
        row[vname] = sub["accuracy"].values[0] * 100 if len(sub) else None
    rows.append(row)
tbl = pd.DataFrame(rows).set_index("sample")

for mname in MODEL_FAMILIES:
    bcol = f"{mname} batch"
    wcol = f"{mname} whole-doc"
    if bcol in tbl.columns and wcol in tbl.columns:
        tbl[f"d({mname.split(':')[0]})"] = tbl[wcol] - tbl[bcol]

active_cols = list(ACTIVE.keys())
delta_cols  = [c for c in tbl.columns if c.startswith("d(")]
all_cols    = active_cols + delta_cols

def _fmt_val(v, w):
    if v is None or (isinstance(v, float) and np.isnan(v)):
        return f"  {'--':>{w}}"
    return f"  {v:>{w-1}.1f}%"

def _fmt_delta(d, w):
    if d is None or (isinstance(d, float) and np.isnan(d)):
        return f"  {'--':>{w}}"
    return f"  {'+' if d >= 0 else ''}{d:>{w-2}.1f}%"

col_w = 16
print(f"  {'Sample':<11}" + "".join(f"  {c:>{col_w}}" for c in all_cols))
print("  " + "-" * (11 + (col_w + 2) * len(all_cols)))
for sname, r in tbl.iterrows():
    line = f"  {sname:<11}"
    for c in active_cols:
        line += _fmt_val(r.get(c), col_w)
    for c in delta_cols:
        line += _fmt_delta(r.get(c), col_w)
    print(line)
print("  " + "-" * (11 + (col_w + 2) * len(all_cols)))

total_line = f"  {'OVERALL':<11}"
for vname in active_cols:
    df, _ = ACTIVE[vname]
    total_line += f"  {df['correct'].sum()/df['total'].sum()*100:>{col_w-1}.1f}%"

for mname in MODEL_FAMILIES:
    bcol = f"{mname} batch"
    wcol = f"{mname} whole-doc"
    key  = f"d({mname.split(':')[0]})"
    if key not in delta_cols:
        continue
    if bcol in ACTIVE and wcol in ACTIVE:
        df_b_ = ACTIVE[bcol][0]
        df_w_ = ACTIVE[wcol][0]
        common = set(df_b_["sample"]) & set(df_w_["sample"])
        if common:
            cb  = df_b_[df_b_["sample"].isin(common)]["correct"].sum()
            cw  = df_w_[df_w_["sample"].isin(common)]["correct"].sum()
            tot = df_b_[df_b_["sample"].isin(common)]["total"].sum()
            d   = (cw - cb) / tot * 100
            note = f"({len(common)}/10)" if len(common) < 10 else ""
            total_line += f"  {'+' if d >= 0 else ''}{d:>{col_w-2}.1f}%{note}"
        else:
            total_line += f"  {'--':>{col_w}}"
    else:
        total_line += f"  {'--':>{col_w}}"
print(total_line)
# Out:
#   Sample       llama3.3:70b batch  llama3.3:70b whole-doc  llama3.1:8b batch  llama3.1:8b whole-doc  qwen2.5vl:7b vision-batch  claude-opus-4-8 batch  claude-opus-4-8 whole-doc  claude-opus-4-8 pdf-direct  claude-opus-4-8 vision-batch       d(llama3.3)       d(llama3.1)  d(claude-opus-4-8)
#   -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   sample1                 97.4%             98.7%             82.1%             93.6%             79.5%            100.0%            100.0%            100.0%            100.0%  +           1.3%  +          11.5%  +           0.0%
#   sample2                 90.7%             79.1%             59.9%             87.2%             55.2%             86.6%             96.5%             92.9%             86.0%           -11.6%  +          27.3%  +           9.9%
#   sample3                 98.6%            100.0%             81.2%             88.4%             62.3%            100.0%            100.0%            100.0%             98.6%  +           1.4%  +           7.2%  +           0.0%
#   sample4                100.0%            100.0%             65.4%             67.9%             98.7%            100.0%            100.0%            100.0%            100.0%  +           0.0%  +           2.6%  +           0.0%
#   sample5                 89.5%             86.0%             62.8%             68.6%             84.9%             93.0%             93.0%             78.6%             93.0%            -3.5%  +           5.8%  +           0.0%
#   sample6                 62.1%             65.5%             55.2%             48.3%             69.0%             72.4%             65.5%            100.0%             72.4%  +           3.4%            -6.9%            -6.9%
#   sample7                 94.1%             94.1%             82.4%             88.2%             94.1%             94.1%             94.1%             50.0%            100.0%  +           0.0%  +           5.9%  +           0.0%
#   sample8                 96.6%            100.0%             66.1%             89.8%             88.1%            100.0%            100.0%            100.0%            100.0%  +           3.4%  +          23.7%  +           0.0%
#   sample9                 98.8%            100.0%             62.4%             84.7%             91.8%            100.0%            100.0%            100.0%            100.0%  +           1.2%  +          22.4%  +           0.0%
#   sample10                95.6%             98.5%             70.6%             98.5%             89.7%            100.0%            100.0%            100.0%            100.0%  +           2.9%  +          27.9%  +           0.0%
#   -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   OVERALL                 93.8%             91.8%             67.2%             83.3%             77.9%             94.9%             96.9%             95.1%             94.7%            -2.0%  +          16.1%  +           2.0%

# %% [markdown]
# ---
# ## Section 3 — Per-sample accuracy
#
# Solid bars = batch, hatched bars = whole-doc.
# Samples where batch and whole-doc diverge sharply indicate documents where
# full-document structural context changes the model's behaviour.

# %%
w   = 0.82 / n_v
x   = list(range(len(SNAMES)))
fig, ax = plt.subplots(figsize=(17, 5))

for i, (name, (df, _)) in enumerate(ACTIVE.items()):
    cfg    = VARIANTS[name]
    alpha  = 0.92 if cfg["hatch"] is None else 0.72
    vals   = [
        df[df["sample"] == s]["accuracy"].values[0] * 100
        if len(df[df["sample"] == s]) else 0
        for s in SNAMES
    ]
    offset = (i - n_v / 2 + 0.5) * w
    bars   = ax.bar([xi + offset for xi in x], vals,
                    width=w, label=name, color=cfg["color"],
                    edgecolor="white", linewidth=0.4,
                    alpha=alpha, hatch=cfg["hatch"])
    for bar, v in zip(bars, vals):
        if v > 0:
            ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.4,
                    f"{v:.0f}", ha="center", va="bottom",
                    fontsize=5.5, color=cfg["color"])

ax.set_xticks(x)
ax.set_xticklabels(SNAMES, rotation=30, ha="right")
ax.set_ylim(30, 122)
ax.set_ylabel("Block-level accuracy (%)")
ax.set_title("Per-sample accuracy — all models and prompt strategies", pad=10)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, _: f"{v:.0f}%"))

handles = []
for mname, methods in MODEL_FAMILIES.items():
    for method, cfg in methods.items():
        vname = f"{mname} {method}"
        if vname in ACTIVE:
            handles.append(mpatches.Patch(
                facecolor=cfg["color"], hatch=cfg["hatch"],
                edgecolor="white", label=vname, alpha=0.85))

ax.legend(handles=handles, framealpha=0.9, ncol=3, loc="upper right", fontsize=9)
sns.despine()
plt.tight_layout()
plt.show()

# %%
hmap_data = []
for name, (df, _) in ACTIVE.items():
    row = [
        df[df["sample"] == s]["accuracy"].values[0] * 100
        if len(df[df["sample"] == s]) else np.nan
        for s in SNAMES
    ]
    hmap_data.append(row)

hmap_df = pd.DataFrame(hmap_data, index=list(ACTIVE.keys()), columns=SNAMES)

fig, ax = plt.subplots(figsize=(14, max(3, n_v * 0.75)))
sns.heatmap(hmap_df, annot=True, fmt=".0f", cmap="RdYlGn",
            vmin=40, vmax=100, linewidths=0.5, linecolor="white",
            ax=ax, cbar_kws={"label": "Accuracy (%)"},
            annot_kws={"size": 9})
ax.set_title("Accuracy heatmap — variant (row) x sample (column)", pad=10)
ax.tick_params(axis="x", rotation=30)
ax.tick_params(axis="y", rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Section 4 — F1 per label
#
# F1 is computed over all 10 samples combined (micro-average per label).
# The two hardest labels are `question.text` and `section.description` — both are
# funder-written text and the model must distinguish them by structural position.

# %%
x2 = list(range(len(LABELS)))
w2 = 0.82 / n_v
fig, ax = plt.subplots(figsize=(15, 5))

for i, (name, (_, conf)) in enumerate(ACTIVE.items()):
    cfg    = VARIANTS[name]
    alpha  = 0.92 if cfg["hatch"] is None else 0.72
    f1_vals = [_f1(conf, l) * 100 for l in LABELS]
    offset  = (i - n_v / 2 + 0.5) * w2
    bars    = ax.bar([xi + offset for xi in x2], f1_vals,
                     width=w2, label=name, color=cfg["color"],
                     edgecolor="white", linewidth=0.4,
                     alpha=alpha, hatch=cfg["hatch"])
    for bar, v in zip(bars, f1_vals):
        if v > 2:
            ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.8,
                    f"{v:.0f}", ha="center", va="bottom",
                    fontsize=6, fontweight="bold", color=cfg["color"])

ax.set_xticks(x2)
ax.set_xticklabels(SHORT, fontsize=10)
ax.set_ylim(0, 130)
ax.set_ylabel("F1 score (%)")
ax.set_title("F1 per label — all models and prompt strategies", pad=10)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, _: f"{v:.0f}%"))
ax.legend(handles=handles, framealpha=0.9, ncol=3, fontsize=9)
sns.despine()
plt.tight_layout()
plt.show()

col_w = 22
print(f"\n  {'Label':<22}" + "".join(f"  {n:>{col_w}}" for n in ACTIVE))
print("  " + "-" * (22 + (col_w + 2) * n_v))
for lbl in LABELS:
    row = f"  {lbl:<22}"
    for name, (_, conf) in ACTIVE.items():
        row += f"  {_f1(conf, lbl)*100:>{col_w-1}.1f}%"
    print(row)
# Out:
#   Label                       llama3.3:70b batch  llama3.3:70b whole-doc       llama3.1:8b batch   llama3.1:8b whole-doc  qwen2.5vl:7b vision-batch   claude-opus-4-8 batch  claude-opus-4-8 whole-doc  claude-opus-4-8 pdf-direct  claude-opus-4-8 vision-batch
#   ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   title                                    90.0%                   90.0%                   66.7%                  100.0%                    0.0%                   95.2%                   95.2%                   94.7%                  100.0%
#   section.title                            79.1%                   81.7%                   60.3%                   69.2%                    0.0%                   90.5%                   88.4%                   98.9%                   90.5%
#   section.description                      87.7%                   78.6%                   41.0%                   74.2%                    0.0%                   84.4%                   99.1%                  100.0%                   83.3%
#   question.text                            70.7%                   29.0%                   26.0%                   47.9%                    0.0%                   62.0%                   88.2%                   81.6%                   60.9%
#   answer.text                              98.9%                   99.1%                   80.1%                   91.5%                   88.6%                   99.9%                   99.6%                  100.0%                   99.7%

# %% [markdown]
# ---
# ## Section 5 — Prompt strategy delta (batch to whole-doc)
#
# For each model family that has both strategies, shows:
# - Left panel: per-sample accuracy delta (green = whole-doc better, red = batch better)
# - Right panel: net blocks gained or lost across all samples

# %%
comparable = [
    mname for mname in MODEL_FAMILIES
    if f"{mname} batch" in ACTIVE and f"{mname} whole-doc" in ACTIVE
]

if not comparable:
    print("No model families have both batch and whole-doc data.")
else:
    n_comp = len(comparable)
    fig, axes = plt.subplots(n_comp, 2, figsize=(16, 3.8 * n_comp), squeeze=False)
    merged_cache = {}

    for row_i, mname in enumerate(comparable):
        df_b  = ACTIVE[f"{mname} batch"][0]
        df_w  = ACTIVE[f"{mname} whole-doc"][0]
        cfg_w = VARIANTS[f"{mname} whole-doc"]

        merged = (
            df_b[["sample", "accuracy", "correct", "total"]]
            .rename(columns={"accuracy": "acc_b", "correct": "cor_b", "total": "tot"})
            .merge(
                df_w[["sample", "accuracy", "correct"]]
                .rename(columns={"accuracy": "acc_w", "correct": "cor_w"}),
                on="sample"
            )
        )
        merged["delta"]  = merged["acc_w"] - merged["acc_b"]
        merged["gained"] = merged["cor_w"] - merged["cor_b"]
        merged = merged.sort_values("sample", key=lambda s: s.map(_snum))
        merged_cache[mname] = merged

        ax = axes[row_i][0]
        bar_colors = ["#16a34a" if d >= 0 else "#dc2626" for d in merged["delta"]]
        bars = ax.bar(merged["sample"], merged["delta"] * 100,
                      color=bar_colors, edgecolor="white", width=0.6)
        for bar, d in zip(bars, merged["delta"] * 100):
            ypos = bar.get_height() + (0.3 if d >= 0 else -1.5)
            ax.text(bar.get_x() + bar.get_width() / 2, ypos,
                    f"{'+' if d >= 0 else ''}{d:.1f}%",
                    ha="center", va="bottom", fontsize=8.5)
        ax.axhline(0, color="#444", linewidth=0.8)
        avg = merged["delta"].mean() * 100
        ax.axhline(avg, color=cfg_w["color"], linestyle="--", linewidth=1.2)
        ax.text(len(merged) - 0.45, avg + 0.4,
                f"mean {avg:+.1f}%", ha="right", fontsize=8.5, color=cfg_w["color"])
        n_note = f" [{len(merged)}/10 samples]" if len(merged) < 10 else ""
        ax.set_ylabel("Accuracy delta (pp)")
        ax.set_title(f"{mname} — accuracy delta (whole-doc minus batch){n_note}", pad=8)
        ax.tick_params(axis="x", rotation=30)
        sns.despine(ax=ax)

        ax = axes[row_i][1]
        blk_colors = ["#16a34a" if g > 0 else ("#dc2626" if g < 0 else "#94a3b8")
                      for g in merged["gained"]]
        ax.bar(merged["sample"], merged["gained"],
               color=blk_colors, edgecolor="white", width=0.6)
        for xi, (_, r) in enumerate(merged.iterrows()):
            if r["gained"] != 0:
                ypos = r["gained"] + (0.15 if r["gained"] > 0 else -0.9)
                ax.text(xi, ypos,
                        f"{'+' if r['gained'] > 0 else ''}{int(r['gained'])}",
                        ha="center", va="bottom", fontsize=8.5)
        ax.axhline(0, color="#444", linewidth=0.8)
        net_total = int(merged["gained"].sum())
        ax.set_ylabel("Blocks gained (+) / lost (-)")
        ax.set_title(f"{mname} — net blocks changed (total {net_total:+d}){n_note}", pad=8)
        ax.tick_params(axis="x", rotation=30)
        sns.despine(ax=ax)

    plt.suptitle("Prompt strategy delta: batch to whole-doc, per model",
                 fontsize=14, y=1.01)
    plt.tight_layout()
    plt.show()

    for mname in comparable:
        merged = merged_cache[mname]
        n_s = len(merged)
        print(f"\n  {mname}  [{n_s}/10 samples compared]")
        print(f"  {'Sample':<12}  {'Batch':>8}  {'Whole-doc':>10}  {'Delta':>8}  {'Net blocks':>11}")
        print("  " + "-" * 57)
        for _, r in merged.iterrows():
            print(f"  {r['sample']:<12}  {r['acc_b']*100:>7.1f}%"
                  f"  {r['acc_w']*100:>9.1f}%"
                  f"  {'+' if r['delta'] >= 0 else ''}{r['delta']*100:>7.1f}%"
                  f"  {'+' if r['gained'] >= 0 else ''}{int(r['gained']):>10}")
        print("  " + "-" * 57)
        tot = merged["tot"].sum()
        cb  = merged["cor_b"].sum()
        cw  = merged["cor_w"].sum()
        net = int(cw - cb)
        print(f"  {'OVERALL':<12}  {cb/tot*100:>7.1f}%"
              f"  {cw/tot*100:>9.1f}%"
              f"  {'+' if (cw-cb) >= 0 else ''}{(cw-cb)/tot*100:>7.1f}%"
              f"  {'+' if net >= 0 else ''}{net:>10}"
              + (f"  [{n_s}/10]" if n_s < 10 else ""))
# Out:
#   llama3.3:70b  [10/10 samples compared]
#   Sample           Batch   Whole-doc     Delta   Net blocks
#   ---------------------------------------------------------
#   sample1          97.4%       98.7%  +    1.3%  +         1
#   sample2          90.7%       79.1%    -11.6%         -20
#   sample3          98.6%      100.0%  +    1.4%  +         1
#   sample4         100.0%      100.0%  +    0.0%  +         0
#   sample5          89.5%       86.0%     -3.5%          -3
#   sample6          62.1%       65.5%  +    3.4%  +         1
#   sample7          94.1%       94.1%  +    0.0%  +         0
#   sample8          96.6%      100.0%  +    3.4%  +         2
#   sample9          98.8%      100.0%  +    1.2%  +         1
#   sample10         95.6%       98.5%  +    2.9%  +         2
#   ---------------------------------------------------------
#   OVERALL          93.8%       91.8%     -2.0%         -15
#
#   llama3.1:8b  [10/10 samples compared]
#   Sample           Batch   Whole-doc     Delta   Net blocks
#   ---------------------------------------------------------
#   sample1          82.1%       93.6%  +   11.5%  +         9
#   sample2          59.9%       87.2%  +   27.3%  +        47
#   sample3          81.2%       88.4%  +    7.2%  +         5
#   sample4          65.4%       67.9%  +    2.6%  +         2
#   sample5          62.8%       68.6%  +    5.8%  +         5
#   sample6          55.2%       48.3%     -6.9%          -2
#   sample7          82.4%       88.2%  +    5.9%  +         1
#   sample8          66.1%       89.8%  +   23.7%  +        14
#   sample9          62.4%       84.7%  +   22.4%  +        19
#   sample10         70.6%       98.5%  +   27.9%  +        19
#   ---------------------------------------------------------
#   OVERALL          67.2%       83.3%  +   16.1%  +       119
#
#   claude-opus-4-8  [10/10 samples compared]
#   Sample           Batch   Whole-doc     Delta   Net blocks
#   ---------------------------------------------------------
#   sample1         100.0%      100.0%  +    0.0%  +         0
#   sample2          86.6%       96.5%  +    9.9%  +        17
#   sample3         100.0%      100.0%  +    0.0%  +         0
#   sample4         100.0%      100.0%  +    0.0%  +         0
#   sample5          93.0%       93.0%  +    0.0%  +         0
#   sample6          72.4%       65.5%     -6.9%          -2
#   sample7          94.1%       94.1%  +    0.0%  +         0
#   sample8         100.0%      100.0%  +    0.0%  +         0
#   sample9         100.0%      100.0%  +    0.0%  +         0
#   sample10        100.0%      100.0%  +    0.0%  +         0
#   ---------------------------------------------------------
#   OVERALL          94.9%       96.9%  +    2.0%  +        15

# %% [markdown]
# ---
# ## Section 6 — Block-level analysis
#
# For each model family with both strategies, breaks down which specific blocks changed.
#
# - Gained: whole-doc correct, batch wrong
# - Lost: whole-doc wrong, batch correct
#
# The confusion shift table reveals what kind of error whole-doc fixes or introduces.

# %%
def block_level_comparison(mname):
    tag_b = VARIANTS[f"{mname} batch"]["tag"]
    tag_w = VARIANTS[f"{mname} whole-doc"]["tag"]
    rows  = []
    for mp in SAMPLES:
        stem  = mp.stem.replace("_dmp", "")
        gold  = extract_gold(mp)
        pp_b  = LLM_DIR / tag_b / f"{stem}.json"
        pp_w  = LLM_DIR / tag_w / f"{stem}.json"
        if not (pp_b.exists() and pp_w.exists()): continue
        blks_b = json.loads(pp_b.read_text(encoding="utf-8"))
        blks_w = json.loads(pp_w.read_text(encoding="utf-8"))
        for i, (bb, bw) in enumerate(zip(blks_b, blks_w)):
            true_lbl = match(bb["text"], gold)
            if true_lbl is None: continue
            lb = bb.get("label", "answer.text")
            lw = bw.get("label", "answer.text")
            rows.append({
                "sample": stem, "block_id": i, "page": bb.get("page", "-"),
                "text": bb["text"][:80], "gold": true_lbl,
                "pred_batch": lb, "pred_whole": lw,
                "batch_ok": lb == true_lbl, "whole_ok": lw == true_lbl,
            })
    df     = pd.DataFrame(rows)
    gained = df[ df["whole_ok"] & ~df["batch_ok"]]
    lost   = df[~df["whole_ok"] &  df["batch_ok"]]
    return df, gained, lost

BLOCK_DATA = {}
for mname in comparable:
    df, gained, lost = block_level_comparison(mname)
    BLOCK_DATA[mname] = (df, gained, lost)
    print(f"{mname}:")
    print(f"  Total matched blocks : {len(df)}")
    print(f"  Both correct         : {(df['whole_ok'] & df['batch_ok']).sum()}")
    print(f"  Gained (whole-doc +) : {len(gained)}")
    print(f"  Lost   (whole-doc -) : {len(lost)}")
    print(f"  Both wrong           : {(~df['whole_ok'] & ~df['batch_ok']).sum()}")
    print(f"  Net change           : {len(gained)-len(lost):+d}")
    print()
# Out:
# llama3.3:70b:
#   Total matched blocks : 726
#   Both correct         : 671
#   Gained (whole-doc +) : 9
#   Lost   (whole-doc -) : 24
#   Both wrong           : 22
#   Net change           : -15
# llama3.1:8b:
#   Total matched blocks : 726
#   Both correct         : 446
#   Gained (whole-doc +) : 171
#   Lost   (whole-doc -) : 52
#   Both wrong           : 57
#   Net change           : +119
# claude-opus-4-8:
#   Total matched blocks : 726
#   Both correct         : 699
#   Gained (whole-doc +) : 19
#   Lost   (whole-doc -) : 4
#   Both wrong           : 4
#   Net change           : +15

# %%
if BLOCK_DATA:
    n_m   = len(BLOCK_DATA)
    fig, axes = plt.subplots(n_m, 2, figsize=(15, 3.8 * n_m), squeeze=False)

    for row_i, (mname, (df, gained, lost)) in enumerate(BLOCK_DATA.items()):
        ax = axes[row_i][0]
        lbl_g = gained["gold"].value_counts().reindex(LABELS, fill_value=0)
        lbl_l = lost["gold"].value_counts().reindex(LABELS, fill_value=0)
        xi    = list(range(len(LABELS)))
        ax.bar([i - 0.2 for i in xi], lbl_g, 0.35,
               label="Gained", color="#16a34a", edgecolor="white")
        ax.bar([i + 0.2 for i in xi], lbl_l, 0.35,
               label="Lost",   color="#dc2626", edgecolor="white")
        ax.set_xticks(xi); ax.set_xticklabels(SHORT, fontsize=9)
        ax.set_ylabel("Block count")
        ax.set_title(f"{mname} — gains/losses by label", pad=7)
        ax.legend(fontsize=9); sns.despine(ax=ax)

        ax = axes[row_i][1]
        samp_g = gained["sample"].value_counts().reindex(SNAMES, fill_value=0)
        samp_l = lost["sample"].value_counts().reindex(SNAMES, fill_value=0)
        xi2    = list(range(len(SNAMES)))
        ax.bar([i - 0.2 for i in xi2], samp_g, 0.35,
               label="Gained", color="#16a34a", edgecolor="white")
        ax.bar([i + 0.2 for i in xi2], samp_l, 0.35,
               label="Lost",   color="#dc2626", edgecolor="white")
        ax.set_xticks(xi2)
        ax.set_xticklabels(SNAMES, rotation=30, ha="right", fontsize=9)
        ax.set_ylabel("Block count")
        ax.set_title(f"{mname} — gains/losses by sample", pad=7)
        ax.legend(fontsize=9); sns.despine(ax=ax)

    plt.suptitle("Block-level changes: whole-doc vs batch", fontsize=14, y=1.01)
    plt.tight_layout()
    plt.show()

    for mname, (_, gained, lost) in BLOCK_DATA.items():
        print(f"\n{'='*60}")
        print(f"  {mname}")
        print(f"{'='*60}")
        if len(gained):
            print("  Errors fixed by whole-doc (batch wrong, whole-doc correct):")
            tbl = (gained.groupby(["gold", "pred_batch"]).size()
                   .reset_index(name="count")
                   .sort_values("count", ascending=False))
            for _, r in tbl.iterrows():
                print(f"    {r['gold']:>22}  misclassified as  {r['pred_batch']:<22}  x {r['count']}")
        if len(lost):
            print("  Errors introduced by whole-doc (whole-doc wrong, batch correct):")
            tbl = (lost.groupby(["gold", "pred_whole"]).size()
                   .reset_index(name="count")
                   .sort_values("count", ascending=False))
            for _, r in tbl.iterrows():
                print(f"    {r['gold']:>22}  misclassified as  {r['pred_whole']:<22}  x {r['count']}")
# Out:
# ============================================================
#   llama3.3:70b
# ============================================================
#   Errors fixed by whole-doc (batch wrong, whole-doc correct):
#                answer.text  misclassified as  section.description     x 5
#              section.title  misclassified as  question.text           x 2
#                answer.text  misclassified as  question.text           x 1
#                answer.text  misclassified as  section.title           x 1
#   Errors introduced by whole-doc (whole-doc wrong, batch correct):
#              question.text  misclassified as  section.description     x 19
#                answer.text  misclassified as  question.text           x 4
#              question.text  misclassified as  section.title           x 1
#
# ============================================================
#   llama3.1:8b
# ============================================================
#   Errors fixed by whole-doc (batch wrong, whole-doc correct):
#                answer.text  misclassified as  question.text           x 55
#                answer.text  misclassified as  section.description     x 47
#                answer.text  misclassified as  section.title           x 26
#              question.text  misclassified as  section.description     x 10
#        section.description  misclassified as  question.text           x 10
#        section.description  misclassified as  answer.text             x 8
#              question.text  misclassified as  answer.text             x 6
#                answer.text  misclassified as  title                   x 6
#        section.description  misclassified as  section.title           x 1
#                      title  misclassified as  answer.text             x 1
#                      title  misclassified as  section.title           x 1
#   Errors introduced by whole-doc (whole-doc wrong, batch correct):
#                answer.text  misclassified as  question.text           x 28
#                answer.text  misclassified as  section.description     x 11
#                answer.text  misclassified as  section.title           x 5
#        section.description  misclassified as  question.text           x 4
#              question.text  misclassified as  section.title           x 2
#              section.title  misclassified as  question.text           x 1
#              section.title  misclassified as  section.description     x 1
#
# ============================================================
#   claude-opus-4-8
# ============================================================
#   Errors fixed by whole-doc (batch wrong, whole-doc correct):
#              question.text  misclassified as  section.description     x 19
#   Errors introduced by whole-doc (whole-doc wrong, batch correct):
#                answer.text  misclassified as  question.text           x 2
#                answer.text  misclassified as  section.title           x 2

# %%
pd.set_option("display.max_colwidth", 80)
for mname, (_, gained, lost) in BLOCK_DATA.items():
    print(f"\n{'='*70}")
    print(f"  {mname}  —  {len(gained)} gained, {len(lost)} lost")
    print(f"{'='*70}")
    if len(gained):
        print("  GAINED (whole-doc correct, batch wrong):")
        display(gained[["sample", "page", "gold", "pred_batch", "pred_whole", "text"]]
                .reset_index(drop=True))
    if len(lost):
        print("  LOST (whole-doc wrong, batch correct):")
        display(lost[["sample", "page", "gold", "pred_batch", "pred_whole", "text"]]
                .reset_index(drop=True))
# Out:
# ======================================================================
#   llama3.3:70b  —  9 gained, 24 lost
# ======================================================================
#   GAINED (whole-doc correct, batch wrong):
#      sample  page           gold           pred_batch     pred_whole  \
# 0   sample1     1    answer.text        question.text    answer.text
# 1   sample2     3    answer.text  section.description    answer.text
# 2   sample3     2  section.title        question.text  section.title
# 3   sample6     1    answer.text        section.title    answer.text
# 4   sample8     2    answer.text  section.description    answer.text
# 5   sample8     2    answer.text  section.description    answer.text
# 6   sample9     3  section.title        question.text  section.title
# 7  sample10     2    answer.text  section.description    answer.text
# 8  sample10     2    answer.text  section.description    answer.text
#
#                                                                               text
# 0                  The following data will be created as a result of this project:
# 1  principles of this Statement, data sharing should make digital research data...
# 2           Policies for access and sharing and appropriate protection and privacy
# 3  1. Types of data. The bulk of the data generated in this project will be 1, ...
# 4  In keeping with standard ethical practices, it is expected that subsequent u...
# 5                                                                          source.
# 6  Policies and provisions for re-use, re-distribution, and production of deriv...
# 7  It is understood that the NSF Engineering Directorate requires data to be ma...
# 8  of three years after conclusion of the award or public release, whichever is...
#   LOST (whole-doc wrong, batch correct):
#      sample  page           gold     pred_batch           pred_whole  \
# 0   sample2     1  question.text  question.text  section.description
# 1   sample2     2  question.text  question.text  section.description
# 2   sample2     2  question.text  question.text  section.description
# 3   sample2     2  question.text  question.text  section.description
# 4   sample2     2  question.text  question.text  section.description
# 5   sample2     2  question.text  question.text  section.description
# 6   sample2     2  question.text  question.text  section.description
# 7   sample2     2  question.text  question.text  section.description
# 8   sample2     2  question.text  question.text  section.description
# 9   sample2     2  question.text  question.text  section.description
# 10  sample2     2  question.text  question.text  section.description
# 11  sample2     2  question.text  question.text  section.description
# 12  sample2     2  question.text  question.text  section.description
# 13  sample2     2  question.text  question.text  section.description
# 14  sample2     2  question.text  question.text  section.description
# 15  sample2     2  question.text  question.text  section.description
# 16  sample2     2  question.text  question.text  section.description
# 17  sample2     2  question.text  question.text  section.description
# 18  sample2     2  question.text  question.text  section.description
# 19  sample2     3  question.text  question.text        section.title
# 20  sample2     4    answer.text    answer.text        question.text
# 21  sample5     2    answer.text    answer.text        question.text
# 22  sample5     2    answer.text    answer.text        question.text
# 23  sample5     2    answer.text    answer.text        question.text
#
#                                                                                text
# 0   Content and Format. A statement of plans for data and metadata content and f...
# 1   the anticipated means for sharing and rationale for any restrictions on who ...
# 2                                                        and under what conditions;
# 3   a timeline for sharing and preservation that addresses both the minimum leng...
# 4   will be available and any anticipated delay to data access after research fi...
# 5   any special requirements for data sharing, for example, proprietary software...
# 6   or interpret data, applicable policies, provisions, and licenses for re-use ...
# 7   for the production of derivatives, including guidance for how data and data ...
# 8                                                                            cited;
# 9   any resources and capabilities (equipment, connections, systems, software, e...
# 10  requested in the research proposal that are needed to meet the stated goals ...
# 11  preservation. (This could reference the relevant section of the associated r...
# 12                                                                 budget request);
# 13  cost/benefit considerations to support whether/where the data will be preser...
# 14  project funding ends and any plans for the transfer of responsibilities for ...
# 15  whether, when, or under what conditions the management responsibility for th...
# 16  will be transferred to a third party (e.g. institutional, or community repos...
# 17  any future decision points regarding the management of the research data inc...
# 18              reevaluate the costs and benefits of data sharing and preservation.
# 19  Rationale. A discussion of the rationale or justification for the proposed d...
# 20  Data Repositories. Senior investigators typically archive relevant data usin...
# 21  Scripts and code for analyses: All scripts and code will be archived in supp...
# 22  Scientist spotlight: All scientist spotlight biographies, assignments, and o...
# 23  Workshop frameworks: Workshop material will be shared with UCSB’s Diversity ...
# ======================================================================
#   llama3.1:8b  —  171 gained, 52 lost
# ======================================================================
#   GAINED (whole-doc correct, batch wrong):
#        sample  page         gold           pred_batch   pred_whole  \
# 0     sample1     1  answer.text        question.text  answer.text
# 1     sample1     1  answer.text                title  answer.text
# 2     sample1     2  answer.text        section.title  answer.text
# 3     sample1     2  answer.text        section.title  answer.text
# 4     sample1     2  answer.text        section.title  answer.text
# ..        ...   ...          ...                  ...          ...
# 166  sample10     1  answer.text  section.description  answer.text
# 167  sample10     1  answer.text        question.text  answer.text
# 168  sample10     2  answer.text  section.description  answer.text
# 169  sample10     2  answer.text        question.text  answer.text
# 170  sample10     2  answer.text  section.description  answer.text
#
#                                                                                 text
# 0                                                               about other studies.
# 1    project’s GitHub website, hosted as part of the UCSD Advance Data Analytics ...
# 2    (i) the SOL-VIDA Study – Data requests may be made by following instructions...
# 3    (ii) the MOCA Study – Data requests may be made by following MOCA Study poli...
# 4    (iii) the PHASE Study – Data requests may be made by following PHASE Study p...
# ..                                                                               ...
# 166  Educational Rights and Privacy Act (FERPA), and any other applicable regulat...
# 167  All materials uploaded to the eScholarship site will be tagged uniformly wit...
# 168  views of the National Science Foundation.” In keeping with standard ethical ...
# 169                        subsequent users of the data will acknowledge the source.
# 170  It is understood that the NSF Engineering Directorate requires data to be ma...
#
# [171 rows x 6 columns]
#   LOST (whole-doc wrong, batch correct):
#      sample  page                 gold           pred_batch  \
# 0   sample1     1        question.text        question.text
# 1   sample2     1          answer.text          answer.text
# 2   sample2     1        question.text        question.text
# 3   sample2     2        section.title        section.title
# 4   sample2     3          answer.text          answer.text
# 5   sample2     4  section.description  section.description
# 6   sample2     4  section.description  section.description
# 7   sample2     4  section.description  section.description
# 8   sample2     4  section.description  section.description
# 9   sample2     4          answer.text          answer.text
# 10  sample2     4          answer.text          answer.text
# 11  sample3     2          answer.text          answer.text
# 12  sample3     2          answer.text          answer.text
# 13  sample3     2          answer.text          answer.text
# 14  sample3     2          answer.text          answer.text
# 15  sample3     2          answer.text          answer.text
# 16  sample3     3          answer.text          answer.text
# 17  sample3     3        section.title        section.title
# 18  sample4     1          answer.text          answer.text
# 19  sample4     1          answer.text          answer.text
# 20  sample4     1          answer.text          answer.text
# 21  sample4     1          answer.text          answer.text
# 22  sample4     1          answer.text          answer.text
# 23  sample4     1          answer.text          answer.text
# 24  sample4     2          answer.text          answer.text
# 25  sample4     2          answer.text          answer.text
# 26  sample4     2          answer.text          answer.text
# 27  sample4     2          answer.text          answer.text
# 28  sample4     2          answer.text          answer.text
# 29  sample4     2          answer.text          answer.text
# 30  sample4     2          answer.text          answer.text
# 31  sample4     2          answer.text          answer.text
# 32  sample4     2          answer.text          answer.text
# 33  sample5     1          answer.text          answer.text
# 34  sample5     1          answer.text          answer.text
# 35  sample5     2          answer.text          answer.text
# 36  sample5     2          answer.text          answer.text
# 37  sample5     2          answer.text          answer.text
# 38  sample5     2          answer.text          answer.text
# 39  sample6     1          answer.text          answer.text
# 40  sample6     1          answer.text          answer.text
# 41  sample6     1          answer.text          answer.text
# 42  sample6     1          answer.text          answer.text
# 43  sample8     1          answer.text          answer.text
# 44  sample8     1          answer.text          answer.text
# 45  sample9     2          answer.text          answer.text
# 46  sample9     2          answer.text          answer.text
# 47  sample9     2          answer.text          answer.text
# 48  sample9     2          answer.text          answer.text
# 49  sample9     2          answer.text          answer.text
# 50  sample9     3          answer.text          answer.text
# 51  sample9     3          answer.text          answer.text
#
#              pred_whole  \
# 0         section.title
# 1         question.text
# 2         section.title
# 3         question.text
# 4         section.title
# 5         question.text
# 6         question.text
# 7         question.text
# 8         question.text
# 9         question.text
# 10        question.text
# 11        section.title
# 12  section.description
# 13  section.description
# 14  section.description
# 15  section.description
# 16        section.title
# 17  section.description
# 18        question.text
# 19        question.text
# 20        question.text
# 21        question.text
# 22  section.description
# 23        question.text
# 24        question.text
# 25        question.text
# 26        question.text
# 27  section.description
# 28        question.text
# 29        question.text
# 30  section.description
# 31        question.text
# 32  section.description
# 33        section.title
# 34        question.text
# 35        question.text
# 36        question.text
# 37        question.text
# 38        section.title
# 39        question.text
# 40        question.text
# 41        question.text
# 42        question.text
# 43  section.description
# 44  section.description
# 45        question.text
# 46        question.text
# 47        question.text
# 48        question.text
# 49        question.text
# 50  section.description
# 51        question.text
#
#                                                                                text
# 0   B. Scientific data that will be preserved and shared, and the rationale for ...
# 1   Roles & Responsibilities. For the proposed research, Director Samuel Stupp w...
# 2   Data Types and Sources. A brief, high-level description of the data to be ge...
# 3                                                                     preservation;
# 4                                                   retention, and data management.
# 5   DMPs should consult and reference available information about data managemen...
# 6   used in the course of the proposed research. In particular, DMPs that explic...
# 7   users should be accompanied by written approval from that facility. In deter...
# 8   available for data management at Office of Science User Facilities, research...
# 9   temperature/time dependent microscopy or X-ray studies), the data may need t...
# 10                           condensed, or minimally processed prior to deposition.
# 11  development and testing. These and the outputs relevant to all key findings ...
# 12  Research records will be archived for a minimum of seven years after final r...
# 13  of a project. If any questions regarding the research, including but not lim...
# 14  allegations, are raised during the seven- year retention period, the PI will...
# 15                                                    questions are fully resolved.
# 16                                                          run by the RIC IT Team.
# 17                                 Additional possible data management requirements
# 18  The longevity analysis will collect data on the length of time clusters have...
# 19  Performance and survey responses will be collected from a minimum of 72 indi...
# 20  Interview data will be collected from a minimum of 24 cluster leads and four...
# 21  The members of the project team will spot check coding on a 10 percent sampl...
# 22  will be conducted. Coders will be instructed on the requirements for produci...
# 23  Data will be backed up on a weekly basis on a hard drive kept in a locked ca...
# 24  and institutions will be stripped of institutional identifications and given...
# 25  include overlapping data is that of Erin Leahey at the University of Arizona...
# 26  Prof. Leahey has collected data on publication rates and publication promine...
# 27  interdisciplinary activity has been conducted at Stanford University by Prof...
# 28  cluster hires. We do not intend to integrate either of these databases with ...
# 29  will be advised of the essential care that must be taken with data collected...
# 30  (private, non-profit or public), and regional location. Following the comple...
# 31  independent. Following the end of the project, we will contact the Inter-Uni...
# 32  on a permanent basis. We do not anticipate additional costs for preparing da...
# 33                                                              Sciences Workshops.
# 34  the format of input data, instructions to run the model, and instructions to...
# 35  database law. CC0 does not exempt those who reuse the data from following co...
# 36  provides encryption of data at rest and in-transit, detailed logging of file...
# 37  submitted to Dryad are curated prior to public release to conform with quali...
# 38  shared on the UCSB’s Dryad Data Repository. The final shareable instructiona...
# 39  practice that all generated data should be straightforwardly reproducible. T...
# 40  the end of the project. Such parties will be responsible for their own versi...
# 41  intellectual rights to the code will be retained by the CU group. Disseminat...
# 42  NSF-funded research computing. We imagine the data being of relevance and st...
# 43  universal data sharing systems envisioned for the near future (see Changing ...
# 44  communications with colleagues. Data that must be withheld long enough to en...
# 45  necessary to construct, e.g., temperature composition phase diagrams, will b...
# 46  Over the course of the project, digital data will be internally stored and s...
# 47  calculation. Furthermore, any structure with a chemical ordering, magnetic o...
# 48  this work, a structured CASM results packet that can easily be queried will ...
# 49  source under a similar LGPL license. Demonstrations on how to access and use...
# 50  All data will be stored in Dryad and will be available under a public domain...
# 51  license (CC0). Note that while a personal ORCID is needed to deposit data in...
# ======================================================================
#   claude-opus-4-8  —  19 gained, 4 lost
# ======================================================================
#   GAINED (whole-doc correct, batch wrong):
#      sample  page           gold           pred_batch     pred_whole  \
# 0   sample2     2  question.text  section.description  question.text
# 1   sample2     2  question.text  section.description  question.text
# 2   sample2     2  question.text  section.description  question.text
# 3   sample2     2  question.text  section.description  question.text
# 4   sample2     2  question.text  section.description  question.text
# 5   sample2     2  question.text  section.description  question.text
# 6   sample2     2  question.text  section.description  question.text
# 7   sample2     2  question.text  section.description  question.text
# 8   sample2     2  question.text  section.description  question.text
# 9   sample2     2  question.text  section.description  question.text
# 10  sample2     2  question.text  section.description  question.text
# 11  sample2     2  question.text  section.description  question.text
# 12  sample2     2  question.text  section.description  question.text
# 13  sample2     2  question.text  section.description  question.text
# 14  sample2     2  question.text  section.description  question.text
# 15  sample2     2  question.text  section.description  question.text
# 16  sample2     2  question.text  section.description  question.text
# 17  sample2     2  question.text  section.description  question.text
# 18  sample2     2  question.text  section.description  question.text
#
#                                                                                text
# 0                                           This should include, where appropriate:
# 1   the anticipated means for sharing and rationale for any restrictions on who ...
# 2                                                        and under what conditions;
# 3   a timeline for sharing and preservation that addresses both the minimum leng...
# 4   will be available and any anticipated delay to data access after research fi...
# 5   any special requirements for data sharing, for example, proprietary software...
# 6   or interpret data, applicable policies, provisions, and licenses for re-use ...
# 7   for the production of derivatives, including guidance for how data and data ...
# 8                                                                            cited;
# 9   any resources and capabilities (equipment, connections, systems, software, e...
# 10  requested in the research proposal that are needed to meet the stated goals ...
# 11  preservation. (This could reference the relevant section of the associated r...
# 12                                                                 budget request);
# 13  cost/benefit considerations to support whether/where the data will be preser...
# 14  project funding ends and any plans for the transfer of responsibilities for ...
# 15  whether, when, or under what conditions the management responsibility for th...
# 16  will be transferred to a third party (e.g. institutional, or community repos...
# 17  any future decision points regarding the management of the research data inc...
# 18              reevaluate the costs and benefits of data sharing and preservation.
#   LOST (whole-doc wrong, batch correct):
#     sample  page         gold   pred_batch     pred_whole  \
# 0  sample2     1  answer.text  answer.text  question.text
# 1  sample2     4  answer.text  answer.text  question.text
# 2  sample6     1  answer.text  answer.text  section.title
# 3  sample6     1  answer.text  answer.text  section.title
#
#                                                                               text
# 0  Roles & Responsibilities. For the proposed research, Director Samuel Stupp w...
# 1  Data Volume. Generally, the volume of data generated by CBES researchers sho...
# 2  1. Types of data. The bulk of the data generated in this project will be 1, ...
# 3  3. Policies for access and sharing. Interested parties will be able to reque...

# %% [markdown]
# ---
# ## Section 7 — Cross-model agreement
#
# For each matched block (aligned to gold), counts how many of the active variants
# labeled it correctly.
#
# - All correct: easy blocks; any model handles them
# - 1–2 correct: ambiguous blocks; model choice matters
# - All wrong: genuinely hard blocks; may need prompt or label refinement
#
# > **PDF-direct excluded:** its paragraph-level blocks do not align index-by-index
# > with pdfplumber blocks, making cross-variant comparison invalid.

# %%
tag_list   = [(n, VARIANTS[n]["tag"]) for n in ACTIVE if not VARIANTS[n]["tag"].endswith("_pdf")]
cross_rows = []

for mp in SAMPLES:
    stem  = mp.stem.replace("_dmp", "")
    gold  = extract_gold(mp)
    bsets = {}
    for name, tag in tag_list:
        pp = LLM_DIR / tag / f"{stem}.json"
        if pp.exists():
            bsets[name] = json.loads(pp.read_text(encoding="utf-8"))
    if not bsets: continue
    ref_name = next(iter(bsets))
    for idx, b in enumerate(bsets[ref_name]):
        true_lbl = match(b["text"], gold)
        if true_lbl is None: continue
        preds     = {n: bsets[n][idx].get("label", "answer.text")
                     for n in bsets if idx < len(bsets[n])}
        n_correct = sum(1 for p in preds.values() if p == true_lbl)
        row = {"sample": stem, "text": b["text"][:100],
               "page": b.get("page", "-"), "true": true_lbl, "n_correct": n_correct}
        for n, _ in tag_list:
            row[f"pred_{n.replace(' ', '_')}"] = preds.get(n, "--")
        cross_rows.append(row)

df_cross = pd.DataFrame(cross_rows)
total    = len(df_cross)
print(f"Cross-model agreement  ({n_v} variants, {total} matched blocks)\n")
for n in range(n_v, -1, -1):
    lbl = {n_v: "all correct", 0: "all wrong"}.get(n, f"{n} correct")
    cnt = (df_cross["n_correct"] == n).sum()
    pct = cnt / total * 100
    bar = chr(9608) * int(pct / 2)
    print(f"  {lbl:<14} {cnt:>4}  ({pct:>5.1f}%)  {bar}")
print(f"\nBlocks all variants got wrong: {(df_cross['n_correct'] == 0).sum()}")
# Out:
# Cross-model agreement  (9 variants, 726 matched blocks)
#
#   all correct       0  (  0.0%)
#   8 correct       351  ( 48.3%)  ████████████████████████
#   7 correct       254  ( 35.0%)  █████████████████
#   6 correct        66  (  9.1%)  ████
#   5 correct        14  (  1.9%)
#   4 correct        23  (  3.2%)  █
#   3 correct        13  (  1.8%)
#   2 correct         3  (  0.4%)
#   1 correct         1  (  0.1%)
#   all wrong         1  (  0.1%)
#
# Blocks all variants got wrong: 1

# %%
palette = ["#bbdefb", "#c4b5fd", "#fde68a", "#fca5a5", "#7c3aed"]
levels  = [n for n in [n_v, n_v-1, n_v-2, 1, 0] if n >= 0]

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

ax = axes[0]
x_lbl2  = sorted(df_cross["sample"].unique(), key=_snum)
bottoms = {s: 0 for s in x_lbl2}
for n, color in zip(levels, palette):
    lbl  = {n_v: "all correct", 0: "all wrong"}.get(n, f"{n} correct")
    vals = [(df_cross[df_cross["sample"] == s]["n_correct"] == n).sum() /
            max(len(df_cross[df_cross["sample"] == s]), 1) * 100 for s in x_lbl2]
    ax.bar(x_lbl2, vals, bottom=[bottoms[s] for s in x_lbl2],
           label=lbl, color=color, edgecolor="white", linewidth=0.3)
    for s, v in zip(x_lbl2, vals): bottoms[s] += v
ax.set_ylim(0, 105)
ax.set_ylabel("% of blocks")
ax.set_title("Agreement per sample", pad=8)
ax.set_xticklabels(x_lbl2, rotation=30, ha="right")
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, _: f"{v:.0f}%"))
ax.legend(loc="lower right", fontsize=9)
sns.despine(ax=ax)

ax = axes[1]
btm = [0] * len(LABELS)
for n, color in list(zip(levels, palette))[1:]:
    lbl  = {0: "all wrong"}.get(n, f"{n} correct")
    vals = [(df_cross[df_cross["true"] == l]["n_correct"] == n).sum() for l in LABELS]
    ax.bar(range(len(LABELS)), vals, bottom=btm, label=lbl,
           color=color, edgecolor="white", linewidth=0.3)
    btm = [b + v for b, v in zip(btm, vals)]
ax.set_xticks(range(len(LABELS)))
ax.set_xticklabels(SHORT, fontsize=10)
ax.set_ylabel("Error count")
ax.set_title("Errors per label", pad=8)
ax.legend(loc="upper right", fontsize=9)
sns.despine(ax=ax)

plt.suptitle(f"Cross-model agreement ({n_v} variants)", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nahid\AppData\Local\Temp\ipykernel_72240\2963406761.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(x_lbl2, rotation=30, ha="right")

# %% [markdown]
# ---
# ## Section 8 — Error drill-down
#
# Filterable view of block-level errors. Edit the variables below to inspect any
# combination of variant, true label, predicted label, or sample.
#
# `"llama3.3:70b batch"`). Set to `""` to view errors across all variants.

# %%
FILTER_VARIANT = "claude-opus-4-8 whole-doc"  # variant name or "" for all
FILTER_TRUE    = ""                             # label name or "" for all
FILTER_PRED    = ""                             # label name or "" for all
FILTER_SAMPLE  = ""                             # e.g. "sample2" or "" for all
ONLY_ERRORS    = True

pred_col  = f"pred_{FILTER_VARIANT.replace(' ', '_')}" if FILTER_VARIANT else None
pred_cols = [c for c in df_cross.columns if c.startswith("pred_")]

mask = pd.Series([True] * len(df_cross), index=df_cross.index)
if ONLY_ERRORS:
    if pred_col and pred_col in df_cross.columns:
        mask &= df_cross[pred_col] != df_cross["true"]
    else:
        mask &= df_cross["n_correct"] < n_v
if FILTER_TRUE:   mask &= df_cross["true"]   == FILTER_TRUE
if FILTER_SAMPLE: mask &= df_cross["sample"] == FILTER_SAMPLE
if FILTER_PRED and pred_col and pred_col in df_cross.columns:
    mask &= df_cross[pred_col] == FILTER_PRED

subset = df_cross[mask].reset_index(drop=True)
print(f"variant={FILTER_VARIANT or 'all'}  true={FILTER_TRUE or 'any'}  "
      f"pred={FILTER_PRED or 'any'}  sample={FILTER_SAMPLE or 'all'}")
print(f"Matching blocks: {len(subset)}\n")
if not subset.empty:
    pd.set_option("display.max_colwidth", 90)
    display(subset[["sample", "page", "true", "n_correct"] + pred_cols + ["text"]])
# Out:
# variant=claude-opus-4-8 whole-doc  true=any  pred=any  sample=all
# Matching blocks: 8
#     sample  page           true  n_correct pred_llama3.3:70b_batch  \
# 0  sample2     1    answer.text          6             answer.text
# 1  sample2     2  section.title          1           question.text
# 2  sample2     4    answer.text          3             answer.text
# 3  sample2     4    answer.text          3           section.title
# 4  sample2     5  section.title          0     section.description
# 5  sample6     1    answer.text          4           section.title
# 6  sample6     1    answer.text          3           section.title
# 7  sample7     1          title          2           section.title
#
#   pred_llama3.3:70b_whole-doc pred_llama3.1:8b_batch  \
# 0                 answer.text            answer.text
# 1         section.description          section.title
# 2               question.text          section.title
# 3               section.title          section.title
# 4         section.description            answer.text
# 5                 answer.text          section.title
# 6               section.title          section.title
# 7               section.title          section.title
#
#   pred_llama3.1:8b_whole-doc pred_qwen2.5vl:7b_vision-batch  \
# 0              question.text                    answer.text
# 1              question.text                    answer.text
# 2              section.title                    answer.text
# 3              section.title                    answer.text
# 4        section.description                    answer.text
# 5              section.title                    answer.text
# 6              section.title                    answer.text
# 7                      title                    answer.text
#
#   pred_claude-opus-4-8_batch pred_claude-opus-4-8_whole-doc  \
# 0                answer.text                  question.text
# 1        section.description                  question.text
# 2              question.text                  question.text
# 3                answer.text                  question.text
# 4        section.description            section.description
# 5                answer.text                  section.title
# 6                answer.text                  section.title
# 7              section.title                  section.title
#
#   pred_claude-opus-4-8_vision-batch  \
# 0                       answer.text
# 1               section.description
# 2                       answer.text
# 3                       answer.text
# 4                       answer.text
# 5                       answer.text
# 6                       answer.text
# 7                             title
#
#                                                                                         text
# 0  Roles & Responsibilities. For the proposed research, Director Samuel Stupp with help f...
# 1                                                                              preservation;
# 2  Data Repositories. Senior investigators typically archive relevant data using their ow...
# 3  Data Volume. Generally, the volume of data generated by CBES researchers should not pr...
# 4                                                                                      data.
# 5    1. Types of data. The bulk of the data generated in this project will be 1, 2, 3, and 4
# 6  3. Policies for access and sharing. Interested parties will be able to request data an...
# 7                                                                 Resource/Data Sharing Plan

# %% [markdown]
# ---
# ## Section 9 — Summary

# %%
print("=" * 70)
print("  Prompt Strategy Comparison — All Models")
print("  10 DMP samples · 5 labels · block-level evaluation")
print("=" * 70)
print()

print(f"  {'Variant':<32}  {'Accuracy':>9}  {'q.text F1':>10}  {'sec.desc F1':>12}")
print("  " + "-" * 70)
best_acc = max(
    ACTIVE[n][0]["correct"].sum() / ACTIVE[n][0]["total"].sum()
    for n in ACTIVE
)
for name, (df, conf) in ACTIVE.items():
    tc, tn = int(df["correct"].sum()), int(df["total"].sum())
    f1_qt  = _f1(conf, "question.text")       * 100
    f1_sd  = _f1(conf, "section.description") * 100
    marker = "  <-- best" if tc/tn == best_acc else ""
    print(f"  {name:<32}  {tc/tn*100:>8.1f}%  {f1_qt:>9.1f}%  {f1_sd:>11.1f}%{marker}")

print()
print("  Prompt strategy effect (batch to whole-doc):")
for mname in comparable:
    df_b, conf_b = ACTIVE[f"{mname} batch"]
    df_w, conf_w = ACTIVE[f"{mname} whole-doc"]
    _, gained, lost = BLOCK_DATA[mname]
    acc_b = df_b["correct"].sum() / df_b["total"].sum() * 100
    acc_w = df_w["correct"].sum() / df_w["total"].sum() * 100
    dqt   = (_f1(conf_w, "question.text")       - _f1(conf_b, "question.text"))       * 100
    dsd   = (_f1(conf_w, "section.description") - _f1(conf_b, "section.description")) * 100
    print(f"    {mname:<20}  acc {acc_b:.1f}% -> {acc_w:.1f}% ({acc_w-acc_b:+.1f}pp)"
          f"  q.text {dqt:+.1f}pp  sec.desc {dsd:+.1f}pp  net blocks {len(gained)-len(lost):+d}")

print()
print("  Cross-model agreement:")
total = len(df_cross)
for n in [n_v, n_v-1]:
    lbl = "all correct" if n == n_v else f"{n}/{n_v} correct"
    cnt = (df_cross["n_correct"] == n).sum()
    print(f"    {lbl:<18}  {cnt:>4}  ({cnt/total*100:.1f}%)")
cnt0 = (df_cross["n_correct"] == 0).sum()
print(f"    {'all wrong':<18}  {cnt0:>4}  ({cnt0/total*100:.1f}%)")

print()
print("=" * 70)
# Out:
# ======================================================================
#   Prompt Strategy Comparison — All Models
#   10 DMP samples · 5 labels · block-level evaluation
# ======================================================================
#
#   Variant                            Accuracy   q.text F1   sec.desc F1
#   ----------------------------------------------------------------------
#   llama3.3:70b batch                    93.8%       70.7%         87.7%
#   llama3.3:70b whole-doc                91.8%       29.0%         78.6%
#   llama3.1:8b batch                     67.2%       26.0%         41.0%
#   llama3.1:8b whole-doc                 83.3%       47.9%         74.2%
#   qwen2.5vl:7b vision-batch             77.9%        0.0%          0.0%
#   claude-opus-4-8 batch                 94.9%       62.0%         84.4%
#   claude-opus-4-8 whole-doc             96.9%       88.2%         99.1%  <-- best
#   claude-opus-4-8 pdf-direct            95.1%       81.6%        100.0%
#   claude-opus-4-8 vision-batch          94.7%       60.9%         83.3%
#
#   Prompt strategy effect (batch to whole-doc):
#     llama3.3:70b          acc 93.8% -> 91.8% (-2.0pp)  q.text -41.7pp  sec.desc -9.1pp  net blocks -15
#     llama3.1:8b           acc 67.2% -> 83.3% (+16.1pp)  q.text +21.9pp  sec.desc +33.3pp  net blocks +119
#     claude-opus-4-8       acc 94.9% -> 96.9% (+2.0pp)  q.text +26.2pp  sec.desc +14.7pp  net blocks +15
#
#   Cross-model agreement:
#     all correct            0  (0.0%)
#     8/9 correct          351  (48.3%)
#     all wrong              1  (0.1%)
#
# ======================================================================
