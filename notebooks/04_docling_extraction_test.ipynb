# %%
from pathlib import Path

from dmpbridge.pdf.docling_extractor import save_docling_outputs

# %%
project_root = Path.cwd().parent

pdf_path = project_root / "data" / "raw_pdfs" / "sample10.pdf"

print("PDF exists:", pdf_path.exists())
# Out:
# PDF exists: True

# %%
docling_result = save_docling_outputs(pdf_path)

print("Extractor:", docling_result["extractor"])
print("Markdown characters:", len(docling_result["markdown"]))
# Out:
# [2026-05-08 12:28:48] Extracting PDF with Docling: sample10.pdf
# [INFO] 2026-05-08 12:28:49,006 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-08 12:28:49,007 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-05-08 12:28:49,018 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Nahid\dmpbridge\venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-05-08 12:28:49,019 [RapidOCR] main.py:50: Using C:\Users\Nahid\dmpbridge\venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-05-08 12:28:49,322 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-08 12:28:49,324 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-05-08 12:28:49,325 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Nahid\dmpbridge\venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %%
print(docling_result["markdown"][:3000])
# Out:
# ## 1. Policy and Practice
#
# We will ensure that the data obtained and this study will be made available to the research community. The  Bourns  College  of  Engineering  (BCOE)  at  UCR,  in  partnership  with  the  UCR  Libraries  and  the California  Digital  Library,  has  established  a  new,  custom  data  management  system  designed  to  make results  of  our  research  readily  and  reliably  accessible.  This  system  combines  two  services  of  the California Digital Library (CDL) for the first time: an eScholarship series, a curated site where all BCOE investigators  can  store  and  disseminate  their  data,  and  EZID  permanent  identifiers  for  long-term identification and management of data resources.
#
# ...

# %%
markdown_path = project_root / "data" / "docling_markdown" / f"{pdf_path.stem}.md"
json_path = project_root / "data" / "docling_json" / f"{pdf_path.stem}.json"

print("Markdown saved:", markdown_path.exists())
print("JSON saved:", json_path.exists())
# Out:
# Markdown saved: True
# JSON saved: True
